# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# # ICML - Run GriddedCCPUnet  Shared or Not

# %%
cd ..
# Out:
# /private/home/yannd/projects/Neural-Process-Family

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = "1"
    
import neuralproc

# %%
import submitit
from train_imgs import main, parse_arguments

log_folder="logs/%j"

# %%
def repeat_list(l, n):
    return [i for i in l for _ in range(n)]

class Run:
    def checkpoint(self, args):
        """Resubmits the same callable with the same arguments but makes sure continnue from last chckpnt."""
        args.is_continue_train=True 
        return submitit.utils.DelayedSubmission(self, args)
    
    def __call__(self, args):
        job_env = submitit.core.utils.JobEnvironment()
        args.starting_run = args.starting_run * job_env.num_tasks + job_env.local_rank
        return main(args)

# %%
datasets_32 = [("cifar10","--is-augment"),("svhn",""),("mnist","")]
models = [("GridedCCPUnet", "--name GridedCCPUnet_large --n-blocks 7 --r-dim 256"),
          ("GridedCCPUnetShared", "--name GridedCCPUnetShared_large --n-blocks 7 --r-dim 256"),
          ("GridedCCPUnet", "--name GridedCCPUnet_small --n-blocks 5 --r-dim 64 "),
          ("GridedCCPUnetShared", "--name GridedCCPUnetShared_small --n-blocks 5 --r-dim 64 ")]

args_32_ccp = [parse_arguments(f"{m} {d} --starting-run {s}  --chckpnt-dirname results/icml/ {d_kwargs} {m_kwargs} --max-epochs 40 --no-retrain".split())
                for s in range(10)
                for d,d_kwargs in datasets_32
                for m,m_kwargs in models]

# %%
executor_32_ccp=submitit.SlurmExecutor(folder=log_folder, max_num_timeout=3)
executor_32_ccp.update_parameters(num_gpus=1, 
                                   cpus_per_task=10, 
                                   mem='32GB',
                                   ntasks_per_node=2,
                                  time=40)

# %%
job_32_ccp = executor_32_ccp.map_array(Run(), args_32_ccp)

# %%
############################################################

# %%
job_32_ccp
# Out:
# [SlurmJob<job_id=20455556_0, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_1, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_2, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_3, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_4, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_5, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_6, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_7, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_8, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_9, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_10, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_11, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_12, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_13, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_14, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_15, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_16, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_17, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_18, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_19, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_20, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_21, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_22, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_23, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_24, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_25, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_26, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_27, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_28, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_29, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_30, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_31, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_32, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_33, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_34, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_35, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_36, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_37, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_38, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_39, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_40, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_41, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_42, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_43, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_44, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_45, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_46, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_47, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_48, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_49, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_50, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_51, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_52, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_53, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_54, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_55, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_56, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_57, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_58, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_59, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_60, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_61, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_62, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_63, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_64, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_65, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_66, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_67, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_68, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_69, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_70, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_71, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_72, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_73, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_74, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_75, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_76, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_77, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_78, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_79, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_80, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_81, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_82, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_83, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_84, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_85, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_86, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_87, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_88, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_89, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_90, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_91, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_92, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_93, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_94, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_95, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_96, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_97, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_98, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_99, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_100, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_101, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_102, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_103, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_104, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_105, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_106, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_107, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_108, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_109, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_110, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_111, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_112, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_113, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_114, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_115, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_116, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_117, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_118, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20455556_119, task_id=None, state="RUNNING">]

# %%
for j in job_32_ccp:
    print("--------------------------------")
    print(j.stdout())
# Out:
# --------------------------------
# submitit INFO (2019-11-27 07:05:20,827) - Starting with JobEnvironment(job_id=20455556_0, hostname=learnfair0433, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:20,827) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_0/20455556_0_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnet_large/run_0 ---
#
# cifar10/GridedCCPUnet_large/run_0 | best epoch: 27 | train loss: -3.2094 | valid loss: -3.3521 | test log likelihood: 3.2411
# cifar10/GridedCCPUnet_large/run_0 100 0.1187
# cifar10/GridedCCPUnet_large/run_0 1000 0.1977
# cifar10/GridedCCPUnet_large/run_0 10000 0.3113
#
# submitit INFO (2019-11-27 07:05:20,826) - Starting with JobEnvironment(job_id=20455556_0, hostname=learnfair0433, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:20,827) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_0/20455556_0_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnet_large/run_1 ---
#
# cifar10/GridedCCPUnet_large/run_1 | best epoch: 31 | train loss: -3.2307 | valid loss: -3.3703 | test log likelihood: 3.2186
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:21,247) - Starting with JobEnvironment(job_id=20455556_1, hostname=learnfair0397, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:21,247) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_1/20455556_1_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnetShared_large/run_0 ---
#
# cifar10/GridedCCPUnetShared_large/run_0 | best epoch: 8 | train loss: -3.2427 | valid loss: -3.3414 | test log likelihood: 3.1554
# cifar10/GridedCCPUnetShared_large/run_0 100 0.12
# cifar10/GridedCCPUnetShared_large/run_0 1000 0.2161
# cifar10/GridedCCPUnetShared_large/run_0 10000 0.2973
#
# submitit INFO (2019-11-27 07:05:21,247) - Starting with JobEnvironment(job_id=20455556_1, hostname=learnfair0397, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:21,247) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_1/20455556_1_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnetShared_large/run_1 ---
#
# cifar10/GridedCCPUnetShared_large/run_1 | best epoch: 15 | train loss: -3.2972 | valid loss: -3.3918 | test log likelihood: 3.1627
# cifar10/GridedCCPUnetShared_large/run_1 100 0.1922
# cifar10/GridedCCPUnetShared_large/run_1 1000 0.2293
# cifar10/GridedCCPUnetShared_large/run_1 10000 0.3034
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:23,145) - Starting with JobEnvironment(job_id=20455556_2, hostname=learnfair0405, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:23,145) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_2/20455556_2_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnet_small/run_0 ---
#
# cifar10/GridedCCPUnet_small/run_0 | best epoch: 27 | train loss: -3.1338 | valid loss: -3.3146 | test log likelihood: 3.2024
# cifar10/GridedCCPUnet_small/run_0 100 0.1533
# cifar10/GridedCCPUnet_small/run_0 1000 0.2787
# cifar10/GridedCCPUnet_small/run_0 10000 0.3341
#
# submitit INFO (2019-11-27 07:05:23,145) - Starting with JobEnvironment(job_id=20455556_2, hostname=learnfair0405, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:23,145) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_2/20455556_2_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnet_small/run_1 ---
#
# cifar10/GridedCCPUnet_small/run_1 | best epoch: 29 | train loss: -3.1675 | valid loss: -3.3237 | test log likelihood: 3.1789
# cifar10/GridedCCPUnet_small/run_1 100 0.1893
# cifar10/GridedCCPUnet_small/run_1 1000 0.2632
# cifar10/GridedCCPUnet_small/run_1 10000 0.3298
# cifar10/GridedCCPUnet_small/run_1 -1 0.3573
# submitit INFO (2019-11-27 07:07:22,130) - Job completed successfully
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:24,211) - Starting with JobEnvironment(job_id=20455556_3, hostname=learnfair0434, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:24,212) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_3/20455556_3_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnetShared_small/run_0 ---
#
# cifar10/GridedCCPUnetShared_small/run_0 | best epoch: 8 | train loss: -3.2422 | valid loss: -3.3365 | test log likelihood: 3.1457
# cifar10/GridedCCPUnetShared_small/run_0 100 0.1532
# cifar10/GridedCCPUnetShared_small/run_0 1000 0.2602
# cifar10/GridedCCPUnetShared_small/run_0 10000 0.3203
#
# submitit INFO (2019-11-27 07:05:24,211) - Starting with JobEnvironment(job_id=20455556_3, hostname=learnfair0434, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:24,212) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_3/20455556_3_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnetShared_small/run_1 ---
#
# cifar10/GridedCCPUnetShared_small/run_1 | best epoch: 15 | train loss: -3.3046 | valid loss: -3.3544 | test log likelihood: 3.1161
# cifar10/GridedCCPUnetShared_small/run_1 100 0.194
# cifar10/GridedCCPUnetShared_small/run_1 1000 0.227
# cifar10/GridedCCPUnetShared_small/run_1 10000 0.3199
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:24,211) - Starting with JobEnvironment(job_id=20455556_4, hostname=learnfair0434, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:24,212) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_4/20455556_4_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnet_large/run_0 ---
#
# svhn/GridedCCPUnet_large/run_0 | best epoch: 31 | train loss: -3.9616 | valid loss: -3.9928 | test log likelihood: 3.9544
#
# submitit INFO (2019-11-27 07:05:24,211) - Starting with JobEnvironment(job_id=20455556_4, hostname=learnfair0434, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:24,212) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_4/20455556_4_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnet_large/run_1 ---
#
# svhn/GridedCCPUnet_large/run_1 | best epoch: 26 | train loss: -3.951 | valid loss: -3.9892 | test log likelihood: 3.9398
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:23,344) - Starting with JobEnvironment(job_id=20455556_5, hostname=learnfair0438, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:23,344) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_5/20455556_5_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnetShared_large/run_0 ---
#
# svhn/GridedCCPUnetShared_large/run_0 | best epoch: 29 | train loss: -4.0033 | valid loss: -3.9843 | test log likelihood: 3.9447
#
# submitit INFO (2019-11-27 07:05:23,344) - Starting with JobEnvironment(job_id=20455556_5, hostname=learnfair0438, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:23,344) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_5/20455556_5_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnetShared_large/run_1 ---
#
# svhn/GridedCCPUnetShared_large/run_1 | best epoch: 9 | train loss: -3.9648 | valid loss: -3.9572 | test log likelihood: 3.9179
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:23,475) - Starting with JobEnvironment(job_id=20455556_6, hostname=learnfair0482, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:23,475) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_6/20455556_6_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnet_small/run_0 ---
#
# svhn/GridedCCPUnet_small/run_0 | best epoch: 20 | train loss: -3.9176 | valid loss: -3.9547 | test log likelihood: 3.9128
#
# submitit INFO (2019-11-27 07:05:23,475) - Starting with JobEnvironment(job_id=20455556_6, hostname=learnfair0482, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:23,475) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_6/20455556_6_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnet_small/run_1 ---
#
# svhn/GridedCCPUnet_small/run_1 | best epoch: 26 | train loss: -3.926 | valid loss: -3.9737 | test log likelihood: 3.9198
# svhn/GridedCCPUnet_small/run_1 100 0.1032959434542102
# svhn/GridedCCPUnet_small/run_1 1000 0.15477105101413643
# svhn/GridedCCPUnet_small/run_1 10000 0.22672095881991394
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:23,148) - Starting with JobEnvironment(job_id=20455556_7, hostname=learnfair0573, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:23,148) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_7/20455556_7_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnetShared_small/run_0 ---
#
# svhn/GridedCCPUnetShared_small/run_0 | best epoch: 15 | train loss: -3.981 | valid loss: -3.9269 | test log likelihood: 3.9018
# svhn/GridedCCPUnetShared_small/run_0 100 0.11904578979717272
# svhn/GridedCCPUnetShared_small/run_0 1000 0.1533881376767056
# svhn/GridedCCPUnetShared_small/run_0 10000 0.20782114320835895
#
# submitit INFO (2019-11-27 07:05:23,148) - Starting with JobEnvironment(job_id=20455556_7, hostname=learnfair0573, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:23,148) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_7/20455556_7_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnetShared_small/run_1 ---
#
# svhn/GridedCCPUnetShared_small/run_1 | best epoch: 9 | train loss: -3.9659 | valid loss: -3.9346 | test log likelihood: 3.8876
# svhn/GridedCCPUnetShared_small/run_1 100 0.11439766441303012
# svhn/GridedCCPUnetShared_small/run_1 1000 0.14459127228027044
# svhn/GridedCCPUnetShared_small/run_1 10000 0.19372311001843884
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:23,148) - Starting with JobEnvironment(job_id=20455556_8, hostname=learnfair0573, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:23,148) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_8/20455556_8_submitted.pkl
#
# --- Loading mnist/GridedCCPUnet_large/run_0 ---
#
# mnist/GridedCCPUnet_large/run_0 | best epoch: 37 | train loss: -1.2516 | valid loss: -1.2685 | test log likelihood: 1.2425
#
# submitit INFO (2019-11-27 07:05:23,147) - Starting with JobEnvironment(job_id=20455556_8, hostname=learnfair0573, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:23,148) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_8/20455556_8_submitted.pkl
#
# --- Loading mnist/GridedCCPUnet_large/run_1 ---
#
# mnist/GridedCCPUnet_large/run_1 | best epoch: 20 | train loss: -1.2445 | valid loss: -1.2611 | test log likelihood: 1.2322
# mnist/GridedCCPUnet_large/run_1 100 0.6018
# mnist/GridedCCPUnet_large/run_1 1000 0.7606
# mnist/GridedCCPUnet_large/run_1 10000 0.8396
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:23,147) - Starting with JobEnvironment(job_id=20455556_9, hostname=learnfair0573, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:23,148) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_9/20455556_9_submitted.pkl
#
# --- Loading mnist/GridedCCPUnetShared_large/run_0 ---
#
# mnist/GridedCCPUnetShared_large/run_0 | best epoch: 18 | train loss: -1.2706 | valid loss: -1.2566 | test log likelihood: 1.2234
# mnist/GridedCCPUnetShared_large/run_0 100 0.5773
# mnist/GridedCCPUnetShared_large/run_0 1000 0.7793
# mnist/GridedCCPUnetShared_large/run_0 10000 0.8508
#
# submitit INFO (2019-11-27 07:05:23,147) - Starting with JobEnvironment(job_id=20455556_9, hostname=learnfair0573, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:23,148) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_9/20455556_9_submitted.pkl
#
# --- Loading mnist/GridedCCPUnetShared_large/run_1 ---
#
# mnist/GridedCCPUnetShared_large/run_1 | best epoch: 33 | train loss: -1.2769 | valid loss: -1.2636 | test log likelihood: 1.2283
# mnist/GridedCCPUnetShared_large/run_1 100 0.5433
# mnist/GridedCCPUnetShared_large/run_1 1000 0.7689
# mnist/GridedCCPUnetShared_large/run_1 10000 0.8461
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:23,145) - Starting with JobEnvironment(job_id=20455556_10, hostname=learnfair0649, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:23,145) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_10/20455556_10_submitted.pkl
#
# --- Loading mnist/GridedCCPUnet_small/run_0 ---
#
# mnist/GridedCCPUnet_small/run_0 | best epoch: 27 | train loss: -1.2247 | valid loss: -1.2499 | test log likelihood: 1.2158
# mnist/GridedCCPUnet_small/run_0 100 0.3955
# mnist/GridedCCPUnet_small/run_0 1000 0.5063
# mnist/GridedCCPUnet_small/run_0 10000 0.6279
# mnist/GridedCCPUnet_small/run_0 -1 0.597
# submitit INFO (2019-11-27 07:07:23,759) - Job completed successfully
#
# submitit INFO (2019-11-27 07:05:23,145) - Starting with JobEnvironment(job_id=20455556_10, hostname=learnfair0649, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:23,145) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_10/20455556_10_submitted.pkl
#
# --- Loading mnist/GridedCCPUnet_small/run_1 ---
#
# mnist/GridedCCPUnet_small/run_1 | best epoch: 20 | train loss: -1.2238 | valid loss: -1.2403 | test log likelihood: 1.2095
# mnist/GridedCCPUnet_small/run_1 100 0.3129
# mnist/GridedCCPUnet_small/run_1 1000 0.4446
# mnist/GridedCCPUnet_small/run_1 10000 0.6128
# mnist/GridedCCPUnet_small/run_1 -1 0.5642
# submitit INFO (2019-11-27 07:07:19,428) - Job completed successfully
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:23,145) - Starting with JobEnvironment(job_id=20455556_11, hostname=learnfair0649, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:23,145) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_11/20455556_11_submitted.pkl
#
# --- Loading mnist/GridedCCPUnetShared_small/run_0 ---
#
# mnist/GridedCCPUnetShared_small/run_0 | best epoch: 18 | train loss: -1.2613 | valid loss: -1.2325 | test log likelihood: 1.1949
# mnist/GridedCCPUnetShared_small/run_0 100 0.4408
# mnist/GridedCCPUnetShared_small/run_0 1000 0.5133
# mnist/GridedCCPUnetShared_small/run_0 10000 0.6503
#
# submitit INFO (2019-11-27 07:05:23,145) - Starting with JobEnvironment(job_id=20455556_11, hostname=learnfair0649, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:23,145) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_11/20455556_11_submitted.pkl
#
# --- Loading mnist/GridedCCPUnetShared_small/run_1 ---
#
# mnist/GridedCCPUnetShared_small/run_1 | best epoch: 33 | train loss: -1.2696 | valid loss: -1.2447 | test log likelihood: 1.2059
# mnist/GridedCCPUnetShared_small/run_1 100 0.3784
# mnist/GridedCCPUnetShared_small/run_1 1000 0.5123
# mnist/GridedCCPUnetShared_small/run_1 10000 0.6599
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:41,886) - Starting with JobEnvironment(job_id=20455556_12, hostname=learnfair0653, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:41,886) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_12/20455556_12_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnet_large/run_2 ---
#
# cifar10/GridedCCPUnet_large/run_2 | best epoch: 23 | train loss: -3.1842 | valid loss: -3.3634 | test log likelihood: 3.2017
#
# submitit INFO (2019-11-27 07:05:41,885) - Starting with JobEnvironment(job_id=20455556_12, hostname=learnfair0653, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:41,886) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_12/20455556_12_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnet_large/run_3 ---
#
# cifar10/GridedCCPUnet_large/run_3 | best epoch: 23 | train loss: -3.2009 | valid loss: -3.3776 | test log likelihood: 3.2157
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:41,885) - Starting with JobEnvironment(job_id=20455556_13, hostname=learnfair0653, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:41,886) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_13/20455556_13_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnetShared_large/run_2 ---
#
# cifar10/GridedCCPUnetShared_large/run_2 | best epoch: 32 | train loss: -3.3649 | valid loss: -3.4207 | test log likelihood: 3.2184
#
# submitit INFO (2019-11-27 07:05:41,885) - Starting with JobEnvironment(job_id=20455556_13, hostname=learnfair0653, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:41,886) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_13/20455556_13_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnetShared_large/run_3 ---
#
# cifar10/GridedCCPUnetShared_large/run_3 | best epoch: 5 | train loss: -3.1949 | valid loss: -3.3149 | test log likelihood: 3.1552
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:51,534) - Starting with JobEnvironment(job_id=20455556_14, hostname=learnfair0657, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:51,545) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_14/20455556_14_submitted.pkl
#
# submitit INFO (2019-11-27 07:05:51,534) - Starting with JobEnvironment(job_id=20455556_14, hostname=learnfair0657, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:51,545) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_14/20455556_14_submitted.pkl
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:44,040) - Starting with JobEnvironment(job_id=20455556_15, hostname=learnfair0662, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:44,040) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_15/20455556_15_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnetShared_small/run_2 ---
#
# cifar10/GridedCCPUnetShared_small/run_2 | best epoch: 10 | train loss: -3.2563 | valid loss: -3.298 | test log likelihood: 3.148
# cifar10/GridedCCPUnetShared_small/run_2 100 0.1926
# cifar10/GridedCCPUnetShared_small/run_2 1000 0.2198
# cifar10/GridedCCPUnetShared_small/run_2 10000 0.3079
#
# submitit INFO (2019-11-27 07:05:44,040) - Starting with JobEnvironment(job_id=20455556_15, hostname=learnfair0662, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:44,040) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_15/20455556_15_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnetShared_small/run_3 ---
#
# cifar10/GridedCCPUnetShared_small/run_3 | best epoch: 5 | train loss: -3.2051 | valid loss: -3.2546 | test log likelihood: 3.0641
# cifar10/GridedCCPUnetShared_small/run_3 100 0.1608
# cifar10/GridedCCPUnetShared_small/run_3 1000 0.2464
# cifar10/GridedCCPUnetShared_small/run_3 10000 0.3249
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:44,412) - Starting with JobEnvironment(job_id=20455556_16, hostname=learnfair0207, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:44,412) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_16/20455556_16_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnet_large/run_2 ---
#
# svhn/GridedCCPUnet_large/run_2 | best epoch: 12 | train loss: -3.9135 | valid loss: -3.9644 | test log likelihood: 3.9224
#
# submitit INFO (2019-11-27 07:05:44,412) - Starting with JobEnvironment(job_id=20455556_16, hostname=learnfair0207, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:44,412) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_16/20455556_16_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnet_large/run_3 ---
#
# svhn/GridedCCPUnet_large/run_3 | best epoch: 13 | train loss: -3.9242 | valid loss: -3.9589 | test log likelihood: 3.9326
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:44,244) - Starting with JobEnvironment(job_id=20455556_17, hostname=learnfair0210, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:44,244) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_17/20455556_17_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnetShared_large/run_2 ---
#
# svhn/GridedCCPUnetShared_large/run_2 | best epoch: 37 | train loss: -4.0089 | valid loss: -3.983 | test log likelihood: 3.9485
#
# submitit INFO (2019-11-27 07:05:44,244) - Starting with JobEnvironment(job_id=20455556_17, hostname=learnfair0210, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:44,244) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_17/20455556_17_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnetShared_large/run_3 ---
#
# svhn/GridedCCPUnetShared_large/run_3 | best epoch: 17 | train loss: -3.9936 | valid loss: -3.9982 | test log likelihood: 3.9435
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:44,047) - Starting with JobEnvironment(job_id=20455556_18, hostname=learnfair0214, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:44,048) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_18/20455556_18_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnet_small/run_2 ---
#
# svhn/GridedCCPUnet_small/run_2 | best epoch: 12 | train loss: -3.8982 | valid loss: -3.9485 | test log likelihood: 3.8971
# svhn/GridedCCPUnet_small/run_2 100 0.12146588813767671
# svhn/GridedCCPUnet_small/run_2 1000 0.15623079287031347
# svhn/GridedCCPUnet_small/run_2 10000 0.20520897357098955
#
# submitit INFO (2019-11-27 07:05:44,047) - Starting with JobEnvironment(job_id=20455556_18, hostname=learnfair0214, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:44,047) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_18/20455556_18_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnet_small/run_3 ---
#
# svhn/GridedCCPUnet_small/run_3 | best epoch: 13 | train loss: -3.8912 | valid loss: -3.9299 | test log likelihood: 3.896
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:49,212) - Starting with JobEnvironment(job_id=20455556_19, hostname=learnfair0210, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:49,212) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_19/20455556_19_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnetShared_small/run_2 ---
#
# svhn/GridedCCPUnetShared_small/run_2 | best epoch: 4 | train loss: -3.93 | valid loss: -3.9309 | test log likelihood: 3.8546
# svhn/GridedCCPUnetShared_small/run_2 100 0.1294176398279041
# svhn/GridedCCPUnetShared_small/run_2 1000 0.15331130915795943
#
# submitit INFO (2019-11-27 07:05:49,174) - Starting with JobEnvironment(job_id=20455556_19, hostname=learnfair0210, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:49,174) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_19/20455556_19_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnetShared_small/run_3 ---
#
# svhn/GridedCCPUnetShared_small/run_3 | best epoch: 17 | train loss: -3.987 | valid loss: -3.9682 | test log likelihood: 3.8988
# svhn/GridedCCPUnetShared_small/run_3 100 0.11835433312845728
# svhn/GridedCCPUnetShared_small/run_3 1000 0.1639136447449293
# svhn/GridedCCPUnetShared_small/run_3 10000 0.21677166564228642
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:51,324) - Starting with JobEnvironment(job_id=20455556_20, hostname=learnfair0214, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:51,324) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_20/20455556_20_submitted.pkl
#
# --- Loading mnist/GridedCCPUnet_large/run_2 ---
#
# mnist/GridedCCPUnet_large/run_2 | best epoch: 38 | train loss: -1.2546 | valid loss: -1.2768 | test log likelihood: 1.2429
# mnist/GridedCCPUnet_large/run_2 100 0.5415
# mnist/GridedCCPUnet_large/run_2 1000 0.7995
#
# submitit INFO (2019-11-27 07:05:51,376) - Starting with JobEnvironment(job_id=20455556_20, hostname=learnfair0214, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:51,376) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_20/20455556_20_submitted.pkl
#
# --- Loading mnist/GridedCCPUnet_large/run_3 ---
#
# mnist/GridedCCPUnet_large/run_3 | best epoch: 15 | train loss: -1.2324 | valid loss: -1.2602 | test log likelihood: 1.2269
# mnist/GridedCCPUnet_large/run_3 100 0.5327
# mnist/GridedCCPUnet_large/run_3 1000 0.7679
# mnist/GridedCCPUnet_large/run_3 10000 0.8491
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:52,744) - Starting with JobEnvironment(job_id=20455556_21, hostname=learnfair0217, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:52,745) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_21/20455556_21_submitted.pkl
#
# --- Loading mnist/GridedCCPUnetShared_large/run_2 ---
#
# mnist/GridedCCPUnetShared_large/run_2 | best epoch: 21 | train loss: -1.2729 | valid loss: -1.2584 | test log likelihood: 1.2236
#
# submitit INFO (2019-11-27 07:05:52,744) - Starting with JobEnvironment(job_id=20455556_21, hostname=learnfair0217, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:52,744) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_21/20455556_21_submitted.pkl
#
# --- Loading mnist/GridedCCPUnetShared_large/run_3 ---
#
# mnist/GridedCCPUnetShared_large/run_3 | best epoch: 32 | train loss: -1.2787 | valid loss: -1.2728 | test log likelihood: 1.2234
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:52,744) - Starting with JobEnvironment(job_id=20455556_22, hostname=learnfair0217, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:52,744) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_22/20455556_22_submitted.pkl
#
# --- Loading mnist/GridedCCPUnet_small/run_2 ---
#
# mnist/GridedCCPUnet_small/run_2 | best epoch: 38 | train loss: -1.2341 | valid loss: -1.2591 | test log likelihood: 1.2215
#
# submitit INFO (2019-11-27 07:05:52,744) - Starting with JobEnvironment(job_id=20455556_22, hostname=learnfair0217, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:52,744) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_22/20455556_22_submitted.pkl
#
# --- Loading mnist/GridedCCPUnet_small/run_3 ---
#
# mnist/GridedCCPUnet_small/run_3 | best epoch: 17 | train loss: -1.2177 | valid loss: -1.2375 | test log likelihood: 1.2098
# mnist/GridedCCPUnet_small/run_3 100 0.3287
# mnist/GridedCCPUnet_small/run_3 1000 0.4879
# mnist/GridedCCPUnet_small/run_3 10000 0.6185
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:53,309) - Starting with JobEnvironment(job_id=20455556_23, hostname=learnfair0222, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:53,309) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_23/20455556_23_submitted.pkl
#
# --- Loading mnist/GridedCCPUnetShared_small/run_2 ---
#
# mnist/GridedCCPUnetShared_small/run_2 | best epoch: 21 | train loss: -1.2654 | valid loss: -1.2335 | test log likelihood: 1.1943
# mnist/GridedCCPUnetShared_small/run_2 100 0.3927
# mnist/GridedCCPUnetShared_small/run_2 1000 0.5512
#
# submitit INFO (2019-11-27 07:05:53,338) - Starting with JobEnvironment(job_id=20455556_23, hostname=learnfair0222, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:53,338) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_23/20455556_23_submitted.pkl
#
# --- Loading mnist/GridedCCPUnetShared_small/run_3 ---
#
# mnist/GridedCCPUnetShared_small/run_3 | best epoch: 32 | train loss: -1.2725 | valid loss: -1.2606 | test log likelihood: 1.2095
# mnist/GridedCCPUnetShared_small/run_3 100 0.3832
# mnist/GridedCCPUnetShared_small/run_3 1000 0.5157
# mnist/GridedCCPUnetShared_small/run_3 10000 0.6536
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:52,702) - Starting with JobEnvironment(job_id=20455556_24, hostname=learnfair0231, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:52,702) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_24/20455556_24_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnet_large/run_4 ---
#
# cifar10/GridedCCPUnet_large/run_4 | best epoch: 17 | train loss: -3.1407 | valid loss: -3.3453 | test log likelihood: 3.2017
# cifar10/GridedCCPUnet_large/run_4 100 0.1621
# cifar10/GridedCCPUnet_large/run_4 1000 0.2201
#
# submitit INFO (2019-11-27 07:05:52,702) - Starting with JobEnvironment(job_id=20455556_24, hostname=learnfair0231, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:52,702) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_24/20455556_24_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnet_large/run_5 ---
#
# cifar10/GridedCCPUnet_large/run_5 | best epoch: 21 | train loss: -3.1793 | valid loss: -3.3478 | test log likelihood: 3.179
# cifar10/GridedCCPUnet_large/run_5 100 0.1582
# cifar10/GridedCCPUnet_large/run_5 1000 0.2261
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:52,728) - Starting with JobEnvironment(job_id=20455556_25, hostname=learnfair0233, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:52,728) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_25/20455556_25_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnetShared_large/run_4 ---
#
# cifar10/GridedCCPUnetShared_large/run_4 | best epoch: 11 | train loss: -3.2952 | valid loss: -3.3495 | test log likelihood: 3.1796
#
# submitit INFO (2019-11-27 07:05:52,728) - Starting with JobEnvironment(job_id=20455556_25, hostname=learnfair0233, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:52,728) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_25/20455556_25_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnetShared_large/run_5 ---
#
# cifar10/GridedCCPUnetShared_large/run_5 | best epoch: 13 | train loss: -3.2888 | valid loss: -3.3329 | test log likelihood: 3.1404
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:52,175) - Starting with JobEnvironment(job_id=20455556_26, hostname=learnfair0241, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:52,175) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_26/20455556_26_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnet_small/run_4 ---
#
# cifar10/GridedCCPUnet_small/run_4 | best epoch: 17 | train loss: -3.08 | valid loss: -3.2918 | test log likelihood: 3.1351
# cifar10/GridedCCPUnet_small/run_4 100 0.1481
# cifar10/GridedCCPUnet_small/run_4 1000 0.2605
# cifar10/GridedCCPUnet_small/run_4 10000 0.3362
#
# submitit INFO (2019-11-27 07:05:52,175) - Starting with JobEnvironment(job_id=20455556_26, hostname=learnfair0241, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:52,175) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_26/20455556_26_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnet_small/run_5 ---
#
# cifar10/GridedCCPUnet_small/run_5 | best epoch: 21 | train loss: -3.1089 | valid loss: -3.3171 | test log likelihood: 3.1504
# cifar10/GridedCCPUnet_small/run_5 100 0.1473
# cifar10/GridedCCPUnet_small/run_5 1000 0.2705
# cifar10/GridedCCPUnet_small/run_5 10000 0.324
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:52,160) - Starting with JobEnvironment(job_id=20455556_27, hostname=learnfair0249, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:52,160) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_27/20455556_27_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnetShared_small/run_4 ---
#
# cifar10/GridedCCPUnetShared_small/run_4 | best epoch: 11 | train loss: -3.2906 | valid loss: -3.325 | test log likelihood: 3.1544
# cifar10/GridedCCPUnetShared_small/run_4 100 0.146
# cifar10/GridedCCPUnetShared_small/run_4 1000 0.2354
# cifar10/GridedCCPUnetShared_small/run_4 10000 0.3308
#
# submitit INFO (2019-11-27 07:05:52,160) - Starting with JobEnvironment(job_id=20455556_27, hostname=learnfair0249, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:52,160) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_27/20455556_27_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnetShared_small/run_5 ---
#
# cifar10/GridedCCPUnetShared_small/run_5 | best epoch: 13 | train loss: -3.2818 | valid loss: -3.3057 | test log likelihood: 3.1246
# cifar10/GridedCCPUnetShared_small/run_5 100 0.1397
# cifar10/GridedCCPUnetShared_small/run_5 1000 0.2639
# cifar10/GridedCCPUnetShared_small/run_5 10000 0.3204
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:52,400) - Starting with JobEnvironment(job_id=20455556_28, hostname=learnfair0254, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:52,400) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_28/20455556_28_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnet_large/run_4 ---
#
# svhn/GridedCCPUnet_large/run_4 | best epoch: 37 | train loss: -3.9616 | valid loss: -3.98 | test log likelihood: 3.962
#
# submitit INFO (2019-11-27 07:05:52,400) - Starting with JobEnvironment(job_id=20455556_28, hostname=learnfair0254, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:52,400) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_28/20455556_28_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnet_large/run_5 ---
#
# svhn/GridedCCPUnet_large/run_5 | best epoch: 9 | train loss: -3.9032 | valid loss: -3.9655 | test log likelihood: 3.9127
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:52,594) - Starting with JobEnvironment(job_id=20455556_29, hostname=learnfair0258, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:52,595) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_29/20455556_29_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnetShared_large/run_4 ---
#
# svhn/GridedCCPUnetShared_large/run_4 | best epoch: 11 | train loss: -3.9707 | valid loss: -3.952 | test log likelihood: 3.9256
#
# submitit INFO (2019-11-27 07:05:52,605) - Starting with JobEnvironment(job_id=20455556_29, hostname=learnfair0258, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:52,605) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_29/20455556_29_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnetShared_large/run_5 ---
#
# svhn/GridedCCPUnetShared_large/run_5 | best epoch: 25 | train loss: -3.9991 | valid loss: -3.9739 | test log likelihood: 3.9429
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:56,668) - Starting with JobEnvironment(job_id=20455556_30, hostname=learnfair0262, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:56,668) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_30/20455556_30_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnet_small/run_4 ---
#
# svhn/GridedCCPUnet_small/run_4 | best epoch: 31 | train loss: -3.9331 | valid loss: -3.9574 | test log likelihood: 3.9219
#
# submitit INFO (2019-11-27 07:05:56,668) - Starting with JobEnvironment(job_id=20455556_30, hostname=learnfair0262, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:56,668) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_30/20455556_30_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnet_small/run_5 ---
#
# svhn/GridedCCPUnet_small/run_5 | best epoch: 9 | train loss: -3.8753 | valid loss: -3.9359 | test log likelihood: 3.8769
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:52,362) - Starting with JobEnvironment(job_id=20455556_31, hostname=learnfair0265, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:52,362) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_31/20455556_31_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnetShared_small/run_4 ---
#
# svhn/GridedCCPUnetShared_small/run_4 | best epoch: 11 | train loss: -3.9694 | valid loss: -3.9265 | test log likelihood: 3.8938
# svhn/GridedCCPUnetShared_small/run_4 100 0.12457744314689613
# svhn/GridedCCPUnetShared_small/run_4 1000 0.16053318992009835
#
# submitit INFO (2019-11-27 07:05:52,355) - Starting with JobEnvironment(job_id=20455556_31, hostname=learnfair0265, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:52,355) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_31/20455556_31_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnetShared_small/run_5 ---
#
# svhn/GridedCCPUnetShared_small/run_5 | best epoch: 25 | train loss: -3.9951 | valid loss: -3.9481 | test log likelihood: 3.9143
# svhn/GridedCCPUnetShared_small/run_5 100 0.13018592501536572
# svhn/GridedCCPUnetShared_small/run_5 1000 0.17478488014751076
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:57,441) - Starting with JobEnvironment(job_id=20455556_32, hostname=learnfair0271, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:57,445) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_32/20455556_32_submitted.pkl
#
# --- Loading mnist/GridedCCPUnet_large/run_4 ---
#
# mnist/GridedCCPUnet_large/run_4 | best epoch: 18 | train loss: -1.241 | valid loss: -1.2616 | test log likelihood: 1.232
#
# submitit INFO (2019-11-27 07:05:57,441) - Starting with JobEnvironment(job_id=20455556_32, hostname=learnfair0271, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:57,443) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_32/20455556_32_submitted.pkl
#
# --- Loading mnist/GridedCCPUnet_large/run_5 ---
#
# mnist/GridedCCPUnet_large/run_5 | best epoch: 37 | train loss: -1.254 | valid loss: -1.27 | test log likelihood: 1.2444
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:57,441) - Starting with JobEnvironment(job_id=20455556_33, hostname=learnfair0271, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:57,445) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_33/20455556_33_submitted.pkl
#
# --- Loading mnist/GridedCCPUnetShared_large/run_4 ---
#
# mnist/GridedCCPUnetShared_large/run_4 | best epoch: 6 | train loss: -1.2455 | valid loss: -1.2401 | test log likelihood: 1.1989
#
# submitit INFO (2019-11-27 07:05:57,441) - Starting with JobEnvironment(job_id=20455556_33, hostname=learnfair0271, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:05:57,445) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_33/20455556_33_submitted.pkl
#
# --- Loading mnist/GridedCCPUnetShared_large/run_5 ---
#
# mnist/GridedCCPUnetShared_large/run_5 | best epoch: 24 | train loss: -1.2753 | valid loss: -1.2565 | test log likelihood: 1.2288
#
# --------------------------------
# submitit INFO (2019-11-27 07:05:52,550) - Starting with JobEnvironment(job_id=20455556_34, hostname=learnfair0279, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:05:52,551) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_34/20455556_34_submitted.pkl
#
# --- Loading mnist/GridedCCPUnet_small/run_4 ---
#
# mnist/GridedCCPUnet_small/run_4 | best epoch: 18 | train loss: -1.2198 | valid loss: -1.242 | test log likelihood: 1.2098
# mnist/GridedCCPUnet_small/run_4 100 0.3792
# mnist/GridedCCPUnet_small/run_4 1000 0.4679
# mnist/GridedCCPUnet_small/run_4 10000 0.6108
#
# ...
# submitit INFO (2019-11-27 07:06:43,743) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_103/20455556_103_submitted.pkl
#
# --------------------------------
# submitit INFO (2019-11-27 07:06:45,597) - Starting with JobEnvironment(job_id=20455556_104, hostname=learnfair0263, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:06:45,597) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_104/20455556_104_submitted.pkl
#
# submitit INFO (2019-11-27 07:06:45,597) - Starting with JobEnvironment(job_id=20455556_104, hostname=learnfair0263, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:06:45,598) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_104/20455556_104_submitted.pkl
#
# --------------------------------
# submitit INFO (2019-11-27 07:06:38,630) - Starting with JobEnvironment(job_id=20455556_105, hostname=learnfair0266, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:06:38,633) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_105/20455556_105_submitted.pkl
#
# submitit INFO (2019-11-27 07:06:38,630) - Starting with JobEnvironment(job_id=20455556_105, hostname=learnfair0266, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:06:38,634) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_105/20455556_105_submitted.pkl
#
# --------------------------------
# submitit INFO (2019-11-27 07:06:36,377) - Starting with JobEnvironment(job_id=20455556_106, hostname=learnfair0272, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:06:36,377) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_106/20455556_106_submitted.pkl
#
# --- Loading mnist/GridedCCPUnet_small/run_16 ---
#
# mnist/GridedCCPUnet_small/run_16 | best epoch: 35 | train loss: -1.2326 | valid loss: -1.2481 | test log likelihood: 1.2163
#
# submitit INFO (2019-11-27 07:06:36,377) - Starting with JobEnvironment(job_id=20455556_106, hostname=learnfair0272, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:06:36,377) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_106/20455556_106_submitted.pkl
#
# --- Loading mnist/GridedCCPUnet_small/run_17 ---
#
# mnist/GridedCCPUnet_small/run_17 | best epoch: 10 | train loss: -1.1995 | valid loss: -1.2272 | test log likelihood: 1.1973
#
# --------------------------------
# submitit INFO (2019-11-27 07:06:36,377) - Starting with JobEnvironment(job_id=20455556_107, hostname=learnfair0272, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:06:36,377) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_107/20455556_107_submitted.pkl
#
# --- Loading mnist/GridedCCPUnetShared_small/run_16 ---
#
# mnist/GridedCCPUnetShared_small/run_16 | best epoch: 10 | train loss: -1.2495 | valid loss: -1.2224 | test log likelihood: 1.1834
#
# submitit INFO (2019-11-27 07:06:36,377) - Starting with JobEnvironment(job_id=20455556_107, hostname=learnfair0272, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:06:36,377) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_107/20455556_107_submitted.pkl
#
# --- Loading mnist/GridedCCPUnetShared_small/run_17 ---
#
# mnist/GridedCCPUnetShared_small/run_17 | best epoch: 17 | train loss: -1.2622 | valid loss: -1.2406 | test log likelihood: 1.2011
#
# --------------------------------
# submitit INFO (2019-11-27 07:06:42,971) - Starting with JobEnvironment(job_id=20455556_108, hostname=learnfair0274, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:06:42,971) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_108/20455556_108_submitted.pkl
#
# submitit INFO (2019-11-27 07:06:42,574) - Starting with JobEnvironment(job_id=20455556_108, hostname=learnfair0274, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:06:42,574) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_108/20455556_108_submitted.pkl
#
# --------------------------------
# submitit INFO (2019-11-27 07:06:41,394) - Starting with JobEnvironment(job_id=20455556_109, hostname=learnfair0274, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:06:41,394) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_109/20455556_109_submitted.pkl
#
# submitit INFO (2019-11-27 07:06:41,393) - Starting with JobEnvironment(job_id=20455556_109, hostname=learnfair0274, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:06:41,394) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_109/20455556_109_submitted.pkl
#
# --------------------------------
# submitit INFO (2019-11-27 07:06:38,143) - Starting with JobEnvironment(job_id=20455556_110, hostname=learnfair0280, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:06:38,143) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_110/20455556_110_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnet_small/run_18 ---
#
#
# submitit INFO (2019-11-27 07:06:38,143) - Starting with JobEnvironment(job_id=20455556_110, hostname=learnfair0280, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:06:38,143) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_110/20455556_110_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnet_small/run_19 ---
#
#
# --------------------------------
# submitit INFO (2019-11-27 07:06:38,143) - Starting with JobEnvironment(job_id=20455556_111, hostname=learnfair0280, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:06:38,143) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_111/20455556_111_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnetShared_small/run_18 ---
#
#
# submitit INFO (2019-11-27 07:06:38,149) - Starting with JobEnvironment(job_id=20455556_111, hostname=learnfair0280, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:06:38,149) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_111/20455556_111_submitted.pkl
# Files already downloaded and verified
# Files already downloaded and verified
#
# --- Loading cifar10/GridedCCPUnetShared_small/run_19 ---
#
#
# --------------------------------
# submitit INFO (2019-11-27 07:06:36,520) - Starting with JobEnvironment(job_id=20455556_112, hostname=learnfair0281, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:06:36,520) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_112/20455556_112_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnet_large/run_18 ---
#
# svhn/GridedCCPUnet_large/run_18 | best epoch: 20 | train loss: -3.944 | valid loss: -3.9818 | test log likelihood: 3.9431
#
# submitit INFO (2019-11-27 07:06:36,520) - Starting with JobEnvironment(job_id=20455556_112, hostname=learnfair0281, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:06:36,520) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_112/20455556_112_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnet_large/run_19 ---
#
# svhn/GridedCCPUnet_large/run_19 | best epoch: 26 | train loss: -3.9493 | valid loss: -3.9734 | test log likelihood: 3.951
#
# --------------------------------
# submitit INFO (2019-11-27 07:06:36,520) - Starting with JobEnvironment(job_id=20455556_113, hostname=learnfair0281, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:06:36,520) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_113/20455556_113_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnetShared_large/run_18 ---
#
# svhn/GridedCCPUnetShared_large/run_18 | best epoch: 17 | train loss: -3.9864 | valid loss: -3.9603 | test log likelihood: 3.9424
#
# submitit INFO (2019-11-27 07:06:36,520) - Starting with JobEnvironment(job_id=20455556_113, hostname=learnfair0281, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:06:36,520) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_113/20455556_113_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnetShared_large/run_19 ---
#
# svhn/GridedCCPUnetShared_large/run_19 | best epoch: 13 | train loss: -3.9804 | valid loss: -3.9662 | test log likelihood: 3.9346
#
# --------------------------------
# submitit INFO (2019-11-27 07:06:36,181) - Starting with JobEnvironment(job_id=20455556_114, hostname=learnfair0290, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:06:36,181) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_114/20455556_114_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnet_small/run_18 ---
#
# svhn/GridedCCPUnet_small/run_18 | best epoch: 20 | train loss: -3.9183 | valid loss: -3.9615 | test log likelihood: 3.9159
#
# submitit INFO (2019-11-27 07:06:36,181) - Starting with JobEnvironment(job_id=20455556_114, hostname=learnfair0290, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:06:36,181) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_114/20455556_114_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnet_small/run_19 ---
#
# svhn/GridedCCPUnet_small/run_19 | best epoch: 26 | train loss: -3.9212 | valid loss: -3.9491 | test log likelihood: 3.919
#
# --------------------------------
# submitit INFO (2019-11-27 07:06:36,181) - Starting with JobEnvironment(job_id=20455556_115, hostname=learnfair0290, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:06:36,181) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_115/20455556_115_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnetShared_small/run_18 ---
#
# svhn/GridedCCPUnetShared_small/run_18 | best epoch: 17 | train loss: -3.9872 | valid loss: -3.9321 | test log likelihood: 3.9081
#
# submitit INFO (2019-11-27 07:06:36,181) - Starting with JobEnvironment(job_id=20455556_115, hostname=learnfair0290, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:06:36,181) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_115/20455556_115_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/projects/Neural-Process-Family/utils/data/../../data/test_32x32.mat
#
# --- Loading svhn/GridedCCPUnetShared_small/run_19 ---
#
# svhn/GridedCCPUnetShared_small/run_19 | best epoch: 13 | train loss: -3.9746 | valid loss: -3.9355 | test log likelihood: 3.8974
#
# --------------------------------
# submitit INFO (2019-11-27 07:06:42,187) - Starting with JobEnvironment(job_id=20455556_116, hostname=learnfair0294, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:06:42,187) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_116/20455556_116_submitted.pkl
#
# submitit INFO (2019-11-27 07:06:42,187) - Starting with JobEnvironment(job_id=20455556_116, hostname=learnfair0294, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:06:42,188) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_116/20455556_116_submitted.pkl
#
# --------------------------------
# submitit INFO (2019-11-27 07:06:48,529) - Starting with JobEnvironment(job_id=20455556_117, hostname=learnfair0298, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:06:48,530) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_117/20455556_117_submitted.pkl
#
# submitit INFO (2019-11-27 07:06:48,529) - Starting with JobEnvironment(job_id=20455556_117, hostname=learnfair0298, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:06:48,556) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_117/20455556_117_submitted.pkl
#
# --------------------------------
# submitit INFO (2019-11-27 07:06:48,529) - Starting with JobEnvironment(job_id=20455556_118, hostname=learnfair0298, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:06:48,556) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_118/20455556_118_submitted.pkl
#
# submitit INFO (2019-11-27 07:06:48,529) - Starting with JobEnvironment(job_id=20455556_118, hostname=learnfair0298, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:06:48,556) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_118/20455556_118_submitted.pkl
#
# --------------------------------
# submitit INFO (2019-11-27 07:06:36,482) - Starting with JobEnvironment(job_id=20455556_119, hostname=learnfair0304, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-27 07:06:36,482) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_119/20455556_119_submitted.pkl
#
# --- Loading mnist/GridedCCPUnetShared_small/run_18 ---
#
# mnist/GridedCCPUnetShared_small/run_18 | best epoch: 20 | train loss: -1.2632 | valid loss: -1.2268 | test log likelihood: 1.1974
#
# submitit INFO (2019-11-27 07:06:36,482) - Starting with JobEnvironment(job_id=20455556_119, hostname=learnfair0304, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-27 07:06:36,482) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20455556_119/20455556_119_submitted.pkl
#
# --- Loading mnist/GridedCCPUnetShared_small/run_19 ---
#
# mnist/GridedCCPUnetShared_small/run_19 | best epoch: 26 | train loss: -1.265 | valid loss: -1.2462 | test log likelihood: 1.1958

# %%
for j in job_32_ccp:
    print("--------------------------------")
    print(j.stderr())
# Out:
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
#
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
#
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
#
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
#
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=6 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:63: UserWarning: hidden_size=64 larger than output=2 and input=32. Setting it to 32.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------

# %%
IS_CANCEL = False

if IS_CANCEL:
    for j in job_32_ccp:
        j.cancel()
