# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# # Run GriddedCCP

# %%
cd ..
# Out:
# /private/home/yannd/projects/Neural-Process-Family

# %%
import neuralproc

# %%
import submitit
from train_imgs import main, parse_arguments

log_folder="logs/%j"

# %%
def repeat_list(l, n):
    return [i for i in l for _ in range(n)]

class Run:
    def checkpoint(self, args):
        """Resubmits the same callable with the same arguments but makes sure continnue from last chckpnt."""
        args.is_continue_train=True 
        return submitit.utils.DelayedSubmission(self, args)
    
    def __call__(self, args):
        job_env = submitit.core.utils.JobEnvironment()
        args.starting_run = args.starting_run * job_env.num_tasks + job_env.local_rank
        return main(args)

# %%
datasets_64 = ["zs-multi-mnist"]

Grided_ccp_kwargs = [(f"GridedCCP_varyingk_circular/k{kernel}", f"--n-blocks 5 --kernel-size {kernel} --init-kernel-size 11 --max-epochs 100 --is-circular-padding")
                     for kernel in [1+2*i for i in range(1,9)]]

args_64_ccp = [parse_arguments("GridedCCP {} --starting-run {} --name {} --chckpnt-dirname results/iclr-rebuttals/ {}".format(d, s, name, other).split())
                for s in range(3)
                for d in datasets_64
                for name,other in Grided_ccp_kwargs]

# %%
executor_64_ccp=submitit.SlurmExecutor(folder=log_folder, max_num_timeout=3)
executor_64_ccp.update_parameters(num_gpus=1, 
                                   time=60*24,  
                                   cpus_per_task=10, 
                                   mem='32GB',
                                   ntasks_per_node=2,
                                  )

# %%
job_64_ccp = executor_64_ccp.map_array(Run(), args_64_ccp)

# %%
############################################################

# %%
job_64_ccp
# Out:
# [SlurmJob<job_id=20002512_0, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20002512_1, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20002512_2, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20002512_3, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20002512_4, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20002512_5, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20002512_6, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20002512_7, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20002512_8, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20002512_9, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20002512_10, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20002512_11, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20002512_12, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20002512_13, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20002512_14, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20002512_15, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20002512_16, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20002512_17, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20002512_18, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20002512_19, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20002512_20, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20002512_21, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20002512_22, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20002512_23, task_id=None, state="RUNNING">]

# %%
for j in job_64_ccp:
    print("--------------------------------")
    print(j.stdout())
# Out:
# --------------------------------
# submitit INFO (2019-11-09 17:01:22,137) - Starting with JobEnvironment(job_id=20002512_0, hostname=learnfair0321, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-09 17:01:22,137) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20002512_0/20002512_0_submitted.pkl
#
# --- Training zs-multi-mnist/GridedCCP_varyingk_circular/k3/run_0 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1       -1.1911       -1.2182     +  284.2800
#       2       -1.2371       -1.2445     +  284.1742
#       3       -1.2633       -1.2803     +  284.0185
#       4       -1.2729       -1.2817     +  284.4361
#       5       -1.2839       -1.2900     +  283.7725
#       6       -1.2885       -1.2994     +  285.1151
#       7       -1.2885       -1.2819        284.7285
#       8       -1.2883       -1.3109     +  283.8929
#       9       -1.2898       -1.2931        283.9183
#      10       -1.2903       -1.2815        284.7642
#      11       -1.2896       -1.2910        284.0539
#      12       -1.2963       -1.3011        284.0060
#      13       -1.2945       -1.2921        283.9054
#      14       -1.2952       -1.2894        284.0140
#      15       -1.2951       -1.2858        283.6415
#      16       -1.2945       -1.3083        283.7901
#      17       -1.2982       -1.2977        283.7739
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# zs-multi-mnist/GridedCCP_varyingk_circular/k3/run_0 | best epoch: 8 | train loss: -1.2885 | valid loss: -1.3109 | test log likelihood: 1.193
# submitit INFO (2019-11-09 18:27:19,690) - Job completed successfully
#
# submitit INFO (2019-11-09 17:01:22,137) - Starting with JobEnvironment(job_id=20002512_0, hostname=learnfair0321, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11
#      38       -1.3064       -1.3159     +  167.2382
#      39       -1.3054       -1.3103        167.1079
#      40       -1.3086       -1.3200     +  166.7511
#      41       -1.3056       -1.3149        165.8260
#      42       -1.3063       -1.3052        166.5521
#      43       -1.3068       -1.3109        167.6170
#      44       -1.3077       -1.2998        166.8726
#      45       -1.3072       -1.3031        167.0505
#      46       -1.3100       -1.3112        166.3742
#      47       -1.3098       -1.3148        166.3675
#      48       -1.3063       -1.3114        169.0764
#      49       -1.3095       -1.3161        168.2605
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# zs-multi-mnist/GridedCCP_varyingk_circular/k5/run_0 | best epoch: 40 | train loss: -1.3092 | valid loss: -1.32 | test log likelihood: 1.2176
# submitit INFO (2019-11-09 20:26:53,393) - Job completed successfully
#
# submitit INFO (2019-11-09 17:01:22,313) - Starting with JobEnvironment(job_id=20002512_1, hostname=learnfair0416, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-09 17:01:22,313) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20002512_1/20002512_1_submitted.pkl
#
# --- Training zs-multi-mnist/GridedCCP_varyingk_circular/k5/run_1 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1       -1.1995       -1.2189     +  330.9627
#       2       -1.2401       -1.2583     +  331.0911
#       3       -1.2659       -1.2838     +  329.2431
#       4       -1.2792       -1.2922     +  330.3158
#       5       -1.2899       -1.2848        330.7195
#       6       -1.2905       -1.2941     +  330.3061
#       7       -1.2926       -1.3006     +  330.1869
#       8       -1.2926       -1.2916        330.8996
#       9       -1.2953       -1.2976        329.0326
#      10       -1.2996       -1.3066     +  329.7593
#      11       -1.2967       -1.2927        329.7853
#      12       -1.2989       -1.2958        330.0462
#      13       -1.2977       -1.3019        330.5848
#      14       -1.3026       -1.3185     +  330.9994
#      15       -1.3002       -1.3055        330.4906
#      16       -1.2984       -1.3025        329.6765
#      17       -1.3022       -1.3028        330.4789
#      18       -1.3029       -1.3115        328.8184
#      19       -1.3045       -1.2948        330.5232
#      20       -1.3020       -1.3110        330.4368
#      21       -1.3043       -1.2965        329.0044
#      22       -1.3030       -1.2928        329.2994
#      23       -1.3067       -1.2942        328.8087
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# zs-multi-mnist/GridedCCP_varyingk_circular/k5/run_1 | best epoch: 14 | train loss: -1.3026 | valid loss: -1.3185 | test log likelihood: 1.2076
# submitit INFO (2019-11-09 19:14:13,212) - Job completed successfully
#
# --------------------------------
# submitit INFO (2019-11-09 17:01:22,313) - Starting with JobEnvironment(job_id=20002512_2, hostname=learnfair0416, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-09 17:01:22,313) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20002512_2/20002512_2_submitted.pkl
#
# --- Training zs-multi-mnist/GridedCCP_varyingk_circular/k7/run_0 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1       -1.2074       -1.2105     +  383.6430
#       2       -1.2591       -1.2669     +  381.9556
#       3       -1.2792       -1.2894     +  382.1721
#       4       -1.2872       -1.2910     +  382.7528
#       5       -1.2924       -1.2964     +  383.2038
#       6       -1.2978       -1.3064     +  382.5936
#       7       -1.2980       -1.2907        382.2660
#       8       -1.2976       -1.3167     +  382.6554
#       9       -1.2997       -1.3018        382.4091
#      10       -1.2995       -1.2812        381.6962
#      11       -1.2979       -1.2995        382.5073
#      12       -1.3044       -1.3092        382.1959
#      13       -1.3030       -1.3014        382.2433
#      14       -1.3041       -1.2978        382.6343
#      15       -1.3043       -1.2957        383.0591
#      16       -1.3033       -1.3127        383.4545
#      17       -1.3061       -1.3041        382.2862
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# zs-multi-mnist/GridedCCP_varyingk_circular/k7/run_0 | best epoch: 8 | train loss: -1.298 | valid loss: -1.3167 | test log likelihood: 1.2063
# submitit INFO (2019-11-09 18:57:00,294) - Job completed successfully
#
# submitit INFO (2019-11-09 17:01:22,313) - Starting with JobEnvironment(job_id=20002512_2, hostname=learnfair0416, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11
#      38       -1.3160       -1.3236     +  213.4613
#      39       -1.3152       -1.3193        213.7057
#      40       -1.3178       -1.3271     +  213.9145
#      41       -1.3145       -1.3224        213.5969
#      42       -1.3154       -1.3168        213.4565
#      43       -1.3165       -1.3193        213.5689
#      44       -1.3172       -1.3100        214.0165
#      45       -1.3167       -1.3130        213.7997
#      46       -1.3186       -1.3197        213.3255
#      47       -1.3186       -1.3233        214.8149
#      48       -1.3156       -1.3201        215.6557
#      49       -1.3183       -1.3244        217.9488
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# zs-multi-mnist/GridedCCP_varyingk_circular/k9/run_0 | best epoch: 40 | train loss: -1.3178 | valid loss: -1.3271 | test log likelihood: 0.9701
# submitit INFO (2019-11-09 21:32:54,766) - Job completed successfully
#
# submitit INFO (2019-11-09 17:01:22,437) - Starting with JobEnvironment(job_id=20002512_3, hostname=learnfair0460, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-09 17:01:22,437) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20002512_3/20002512_3_submitted.pkl
#
# --- Training zs-multi-mnist/GridedCCP_varyingk_circular/k9/run_1 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1       -1.2066       -1.2469     +  445.2848
#       2       -1.2554       -1.2676     +  444.5185
#       3       -1.2707       -1.2861     +  456.2545
#       4       -1.2829       -1.2951     +  486.9836
#       5       -1.2938       -1.2933        488.1358
#       6       -1.2975       -1.3108     +  495.9961
#       7       -1.3003       -1.3078        488.4190
#       8       -1.3015       -1.3068        527.1822
#       9       -1.3030       -1.3054        548.4701
#      10       -1.3082       -1.3143     +  545.7290
#      11       -1.3064       -1.3039        488.5322
#      12       -1.3083       -1.3050        493.6070
#      13       -1.3071       -1.3112        487.8460
#      14       -1.3110       -1.3254     +  468.0002
#      15       -1.3100       -1.3139        490.5012
#      16       -1.3084       -1.3105        483.3434
#      17       -1.3114       -1.3117        484.0645
#      18       -1.3121       -1.3193        494.3654
#      19       -1.3134       -1.3044        473.7457
#      20       -1.3117       -1.3183        471.2094
#      21       -1.3127       -1.3062        488.6128
#      22       -1.3123       -1.3041        477.5955
#      23       -1.3152       -1.3045        488.6415
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# zs-multi-mnist/GridedCCP_varyingk_circular/k9/run_1 | best epoch: 14 | train loss: -1.311 | valid loss: -1.3254 | test log likelihood: 1.1837
# submitit INFO (2019-11-09 20:17:34,066) - Job completed successfully
#
# --------------------------------
# submitit INFO (2019-11-09 17:01:22,137) - Starting with JobEnvironment(job_id=20002512_4, hostname=learnfair0472, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-09 17:01:22,137) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20002512_4/20002512_4_submitted.pkl
#
# --- Training zs-multi-mnist/GridedCCP_varyingk_circular/k11/run_0 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1       -1.2046       -1.2371     +  556.0464
#       2       -1.2538       -1.2608     +  589.0469
#       3       -1.2688       -1.2780     +  599.3273
#       4       -1.2813       -1.2882     +  580.4236
#       5       -1.2933       -1.2993     +  599.6767
#       6       -1.3004       -1.3111     +  590.6787
#       7       -1.3029       -1.2965        592.4759
#       8       -1.3033       -1.3208     +  586.1300
#       9       -1.3061       -1.3076        592.0839
#      10       -1.3064       -1.2926        589.1586
#      11       -1.3056       -1.3061        603.5822
#      12       -1.3112       -1.3138        591.7453
#      13       -1.3096       -1.3088        590.8707
#      14       -1.3112       -1.3078        582.5532
#      15       -1.3111       -1.3040        573.6063
#      16       -1.3110       -1.3216     +  566.8238
#      17       -1.3137       -1.3128        569.1140
#      18       -1.3130       -1.3116        555.4122
#      19       -1.3107       -1.3147        579.5500
#      20       -1.3108       -1.3194        466.0434
#      21       -1.3139       -1.3178        271.1677
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# zs-multi-mnist/GridedCCP_varyingk_circular/k15/run_0 | best epoch: 8 | train loss: -1.3055 | valid loss: -1.3225 | test log likelihood: 1.1975
# submitit INFO (2019-11-09 21:23:06,924) - Job completed successfully
#
# submitit INFO (2019-11-09 17:01:22,397) - Starting with JobEnvironment(job_id=20002512_6, hostname=learnfair0487, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-09 17:01:22,398) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20002512_6/20002512_6_submitted.pkl
#
# --- Training zs-multi-mnist/GridedCCP_varyingk_circular/k15/run_1 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1       -1.2104       -1.2526     +  647.7996
#       2       -1.2609       -1.2766     +  646.7767
#       3       -1.2785       -1.2893     +  646.8286
#       4       -1.2859       -1.2951     +  649.6599
#       5       -1.2980       -1.2938        646.9100
#       6       -1.3013       -1.3134     +  646.5474
#       7       -1.3046       -1.3111        647.1187
#       8       -1.3053       -1.3054        649.8677
#       9       -1.3071       -1.3074        646.6041
#      10       -1.3114       -1.3161     +  646.2868
#      11       -1.3098       -1.3079        646.4780
#      12       -1.3112       -1.3091        649.6920
#      13       -1.3106       -1.3136        647.5412
#      14       -1.3140       -1.3272     +  646.4908
#      15       -1.3133       -1.3164        647.3263
#      16       -1.3122       -1.3144        649.7709
#      17       -1.3148       -1.3152        643.3937
#      18       -1.3156       -1.3222        642.4396
#      19       -1.3170       -1.3090        646.6152
#      20       -1.3147       -1.3215        649.0562
#      21       -1.3161       -1.3102        646.9561
#      22       -1.3153       -1.3085        645.8818
#      23       -1.3179       -1.3084        646.6760
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# zs-multi-mnist/GridedCCP_varyingk_circular/k15/run_1 | best epoch: 14 | train loss: -1.314 | valid loss: -1.3272 | test log likelihood: 1.1437
# submitit INFO (2019-11-09 21:21:22,709) - Job completed successfully
#
# --------------------------------
# submitit INFO (2019-11-09 17:01:22,397) - Starting with JobEnvironment(job_id=20002512_7, hostname=learnfair0487, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-09 17:01:22,398) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20002512_7/20002512_7_submitted.pkl
#
# --- Training zs-multi-mnist/GridedCCP_varyingk_circular/k17/run_0 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1       -1.2092       -1.2442     +  883.8089
#       2       -1.2634       -1.2708     +  874.6900
#       3       -1.2796       -1.2892     +  884.2683
#       4       -1.2897       -1.2944     +  876.2327
#       5       -1.3001       -1.3037     +  883.9229
#       6       -1.3051       -1.3134     +  876.2093
#       7       -1.3059       -1.3023        884.4599
#       8       -1.3062       -1.3218     +  876.2983
#       9       -1.3083       -1.3087        884.2865
#      10       -1.3088       -1.3014        875.0601
#      11       -1.3085       -1.3092        883.7038
#      12       -1.3134       -1.3158        875.8337
#      13       -1.3121       -1.3102        884.2024
#      14       -1.3129       -1.3098        876.6803
#      15       -1.3133       -1.3040        882.8593
#      16       -1.3127       -1.3225     +  876.8777
#      17       -1.3159       -1.3126        883.8356
#      18       -1.3146       -1.3154        874.9014
#      19       -1.3128       -1.3209        885.9663
#      20       -1.3128       -1.3204        875.6048
#      21       -1.3158       -1.3193        884.8876
#      22       -1.3154       -1.3161        876.9788
#      23       -1.3148       -1.3249     +  883.9581
#      24       -1.3158       -1.3138        876.0838
#      25       -1.3178       -1.3116        415.5307
#      26       -1.3166       -1.3122        391.0158
#      27       -1.3178       -1.3242        396.6250
#      28       -1.3143       -1.3083        388.3974
#      29       -1.3195       -1.3085        392.7887
#      30       -1.3188       -1.3162        391.1376
#      31       -1.3181       -1.3165        395.3523
#      32       -1.3179       -1.3249        393.2044
#      33       -1.3179       -1.3146        388.2874
#
# submitit INFO (2019-11-09 17:01:22,397) - Starting with JobEnvironment(job_id=20002512_7, hostname=learnfair0487, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-09 17:01:22,398) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20002512_7/20002512_7_submitted.pkl
#
# --- Training zs-multi-mnist/GridedCCP_varyingk_circular/k17/run_1 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1       -1.2150       -1.2592     +  883.7175
#       2       -1.2661       -1.2742     +  874.4195
#       3       -1.2793       -1.2926     +  884.4313
#       4       -1.2886       -1.2955     +  876.2878
#       5       -1.3009       -1.2994     +  883.9255
#       6       -1.3030       -1.3151     +  876.1100
#       7       -1.3061       -1.3125        884.2734
#       8       -1.3065       -1.3103        876.4971
#       9       -1.3085       -1.3088        884.1626
#      10       -1.3122       -1.3174     +  875.2896
#      11       -1.3105       -1.3083        883.7125
#      12       -1.3123       -1.3102        875.8939
#      13       -1.3112       -1.3150        884.1672
#      14       -1.3154       -1.3277     +  876.7623
#      15       -1.3137       -1.3176        882.8923
#      16       -1.3127       -1.3150        876.8136
#      17       -1.3158       -1.3159        883.9276
#      18       -1.3160       -1.3225        874.8785
#      19       -1.3177       -1.3097        886.0654
#      20       -1.3156       -1.3216        875.4029
#      21       -1.3163       -1.3110        884.9117
#      22       -1.3164       -1.3091        877.0528
#      23       -1.3188       -1.3095        883.9950
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# zs-multi-mnist/GridedCCP_varyingk_circular/k17/run_1 | best epoch: 14 | train loss: -1.3154 | valid loss: -1.3277 | test log likelihood: 1.1828
# submitit INFO (2019-11-09 22:54:44,795) - Job completed successfully
#
# --------------------------------
# submitit INFO (2019-11-09 17:01:22,137) - Starting with JobEnvironment(job_id=20002512_8, hostname=learnfair0692, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-09 17:01:22,137) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20002512_8/20002512_8_submitted.pkl
#
# --- Training zs-multi-mnist/GridedCCP_varyingk_circular/k3/run_2 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1       -1.1889       -1.2251     +  239.5165
#       2       -1.2378       -1.2200        227.9410
#       3       -1.2664       -1.2768     +  230.7568
#       4       -1.2783       -1.2828     +  228.6685
#       5       -1.2855       -1.2860     +  231.0948
#       6       -1.2879       -1.2996     +  230.3424
#       7       -1.2889       -1.2981        234.3677
#       8       -1.2932       -1.2907        248.5694
#       9       -1.2896       -1.3052     +  247.8075
#      10       -1.2941       -1.2906        247.0240
#      11       -1.2948       -1.2865        246.0745
#      12       -1.2956       -1.3017        250.9540
#      13       -1.2987       -1.2862        243.7227
#      14       -1.2932       -1.2927        242.9486
#      15       -1.2956       -1.2947        245.2042
#      16       -1.2960       -1.2919        250.0915
#      17       -1.2963       -1.2960        237.9605
#      18       -1.2999       -1.2866        236.6385
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# zs-multi-mnist/GridedCCP_varyingk_circular/k3/run_2 | best epoch: 9 | train loss: -1.2932 | valid loss: -1.3052 | test log likelihood: 1.1914
# submitit INFO (2019-11-09 18:18:07,184) - Job completed successfully
#
# submitit INFO (2019-11-09 17:01:22,137) - Starting with JobEnvironment(job_id=20002512_8, hostname=learnfair0692, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-09 17:01:22,137) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20002512_8/20002512_8_submitted.pkl
#
# --- Training zs-multi-mnist/GridedCCP_varyingk_circular/k3/run_3 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1       -1.1953       -1.2438     +  439.1801
#       2       -1.2352       -1.2443     +  460.0163
#       3       -1.2615       -1.2821     +  451.4399
#       4       -1.2814       -1.2914     +  415.2961
#       5       -1.2794       -1.2926     +  389.1383
#       6       -1.2847       -1.2967     +  388.9396
#       7       -1.2869       -1.2906        383.4802
#       8       -1.2915       -1.2920        403.0809
#       9       -1.2914       -1.2881        388.5505
---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1       -1.2029       -1.2374     +  391.0298
#       2       -1.2498       -1.2495     +  391.9234
#       3       -1.2741       -1.2818     +  391.0937
#       4       -1.2850       -1.2893     +  391.3612
#       5       -1.2923       -1.2936     +  390.6259
#       6       -1.2953       -1.3052     +  391.0202
#       7       -1.2977       -1.3047        390.6510
#       8       -1.3017       -1.2986        392.4663
#       9       -1.2976       -1.3144     +  392.0300
#      10       -1.3011       -1.2988        390.7843
#      11       -1.3021       -1.2955        391.3333
#      12       -1.3037       -1.3087        391.1977
#      13       -1.3064       -1.2947        390.7468
#      14       -1.3013       -1.3010        391.9317
#      15       -1.3044       -1.3021        391.0171
#      16       -1.3032       -1.2992        391.2808
#      17       -1.3048       -1.3051        392.1248
#      18       -1.3080       -1.2954        392.1982
#      19       -1.3064       -1.3145     +  392.2944
#      20       -1.3077       -1.3142        390.3987
#      21       -1.3063       -1.3068        391.2923
#      22       -1.3079       -1.3075        391.5223
# ...
# submitit INFO (2019-11-09 21:33:09,491) - Job completed successfully
#
# submitit INFO (2019-11-09 17:01:27,493) - Starting with JobEnvironment(job_id=20002512_20, hostname=learnfair0729, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-09 17:01:27,493) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20002512_20/20002512_20_submitted.pkl
#
# --- Training zs-multi-mnist/GridedCCP_varyingk_circular/k11/run_5 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1       -1.2094       -1.2471     +  534.9784
#       2       -1.2499       -1.2613     +  535.1584
#       3       -1.2648       -1.2771     +  534.3819
#       4       -1.2809       -1.2876     +  535.6943
#       5       -1.2903       -1.2907     +  535.6796
#       6       -1.2996       -1.3069     +  534.6001
#       7       -1.3030       -1.2985        535.1308
#       8       -1.3037       -1.3103     +  535.0400
#       9       -1.3039       -1.3030        535.9362
#      10       -1.3086       -1.3094        535.0616
#      11       -1.3087       -1.3087        534.2985
#      12       -1.3078       -1.3134     +  535.7349
#      13       -1.3087       -1.3182     +  536.0114
#      14       -1.3105       -1.3075        535.5354
#      15       -1.3135       -1.3144        534.5444
#      16       -1.3108       -1.3163        534.7774
#      17       -1.3094       -1.2993        534.7340
#      18       -1.3097       -1.3240     +  534.3343
#      19       -1.3151       -1.3192        534.3165
#      20       -1.3134       -1.3138        534.9879
#      21       -1.3119       -1.3179        535.2672
#      22       -1.3143       -1.3188        535.5454
#      23       -1.3133       -1.3084        535.5491
#      24       -1.3135       -1.3163        535.2809
#      25       -1.3164       -1.3160        534.9910
#      26       -1.3155       -1.3183        529.9151
#      27       -1.3153       -1.3129        528.9297
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# zs-multi-mnist/GridedCCP_varyingk_circular/k11/run_5 | best epoch: 18 | train loss: -1.3135 | valid loss: -1.324 | test log likelihood: 0.9898
# submitit INFO (2019-11-09 21:11:55,220) - Job completed successfully
#
# --------------------------------
# submitit INFO (2019-11-09 17:01:27,920) - Starting with JobEnvironment(job_id=20002512_21, hostname=learnfair0744, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-09 17:01:27,920) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20002512_21/20002512_21_submitted.pkl
#
# --- Training zs-multi-mnist/GridedCCP_varyingk_circular/k13/run_4 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1       -1.2057       -1.2115     +  559.2428
#       2       -1.2582       -1.2585     +  557.4941
#       3       -1.2712       -1.2871     +  555.5796
#       4       -1.2797       -1.2947     +  570.6527
#       5       -1.2925       -1.2896        573.7280
#       6       -1.3027       -1.3029     +  571.7816
#       7       -1.3035       -1.3039     +  576.3247
#       8       -1.3056       -1.2989        560.3826
#       9       -1.3082       -1.3120     +  551.7071
#      10       -1.3067       -1.2956        563.5209
#      11       -1.3045       -1.3031        573.0411
#      12       -1.3118       -1.3103        549.6711
#      13       -1.3108       -1.3132     +  561.6455
#      14       -1.3108       -1.3072        550.8415
#      15       -1.3126       -1.3170     +  556.5769
#      16       -1.3135       -1.3203     +  554.8242
#      17       -1.3114       -1.3107        550.4552
#      18       -1.3133       -1.3088        552.6785
#      19       -1.3143       -1.3160        560.6639
#      20       -1.3132       -1.3175        570.2369
#      21       -1.3135       -1.3154        556.9245
#      22       -1.3159       -1.3273     +  562.3838
#      23       -1.3142       -1.3279     +  572.2422
#      24       -1.3146       -1.3143        562.7034
#      25       -1.3151       -1.3165        569.7417
#      26       -1.3159       -1.3160        560.2805
#      27       -1.3162       -1.3227        570.2438
#      28       -1.3171       -1.3194        595.8333
#      29       -1.3160       -1.3166        616.7866
#      30       -1.3165       -1.3180        589.9895
#      31       -1.3155       -1.3173        578.8613
#      32       -1.3166       -1.3173        609.2345
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# zs-multi-mnist/GridedCCP_varyingk_circular/k13/run_4 | best epoch: 23 | train loss: -1.3159 | valid loss: -1.3279 | test log likelihood: 1.1494
# submitit INFO (2019-11-09 22:15:15,588) - Job completed successfully
#
# submitit INFO (2019-11-09 17:01:27,920) - Starting with JobEnvironment(job_id=20002512_21, hostname=learnfair0744, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-09 17:01:27,920) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20002512_21/20002512_21_submitted.pkl
#
# --- Training zs-multi-mnist/GridedCCP_varyingk_circular/k13/run_5 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1       -1.2092       -1.2497     +  747.5114
#       2       -1.2580       -1.2768     +  754.1651
#       3       -1.2743       -1.2863     +  727.9718
#       4       -1.2887       -1.2949     +  729.0439
#       5       -1.2965       -1.2948        719.1287
#       6       -1.3022       -1.3123     +  732.4079
#       7       -1.3059       -1.3003        759.4282
#       8       -1.3058       -1.3115        728.0896
#       9       -1.3063       -1.3033        753.7917
#      10       -1.3105       -1.3099        744.8630
#      11       -1.3105       -1.3111        750.8748
#      12       -1.3092       -1.3154     +  755.1954
#      13       -1.3103       -1.3195     +  754.9173
#      14       -1.3118       -1.3065        744.5861
#      15       -1.3154       -1.3163        735.9744
#      16       -1.3118       -1.3170        742.8828
#      17       -1.3113       -1.3006        729.6205
#      18       -1.3112       -1.3248     +  730.6879
#      19       -1.3163       -1.3221        734.7335
#      20       -1.3147       -1.3147        750.2616
#      21       -1.3129       -1.3184        709.3093
#      22       -1.3154       -1.3195        669.3221
#      23       -1.3141       -1.3103        684.1405
#      24       -1.3148       -1.3170        717.7079
#      25       -1.3170       -1.3173        680.4150
#      26       -1.3164       -1.3189        602.9852
#      27       -1.3159       -1.3134        317.0969
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# zs-multi-mnist/GridedCCP_varyingk_circular/k13/run_5 | best epoch: 18 | train loss: -1.3154 | valid loss: -1.3248 | test log likelihood: 1.0311
# submitit INFO (2019-11-09 22:28:11,184) - Job completed successfully
#
# --------------------------------
# submitit INFO (2019-11-09 17:01:27,920) - Starting with JobEnvironment(job_id=20002512_22, hostname=learnfair0744, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-09 17:01:27,920) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20002512_22/20002512_22_submitted.pkl
#
# --- Training zs-multi-mnist/GridedCCP_varyingk_circular/k15/run_4 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1       -1.2099       -1.2351     +  767.5982
#       2       -1.2657       -1.2690     +  767.2323
#       3       -1.2770       -1.2922     +  766.7787
#       4       -1.2869       -1.2989     +  766.4073
#       5       -1.2965       -1.2919        765.8047
#       6       -1.3048       -1.3072     +  766.8965
#       7       -1.3055       -1.3071        766.0538
#       8       -1.3067       -1.2993        766.1967
#       9       -1.3097       -1.3134     +  766.0672
#      10       -1.3074       -1.3035        766.7212
#      11       -1.3098       -1.3125        766.9079
#      12       -1.3131       -1.3117        764.3502
#      13       -1.3113       -1.3141     +  764.6807
#      14       -1.3122       -1.3091        766.4854
#      15       -1.3140       -1.3173     +  766.3844
#      16       -1.3146       -1.3193     +  766.3384
#      17       -1.3123       -1.3106        766.7291
#      18       -1.3145       -1.3110        767.1074
#      19       -1.3155       -1.3167        766.5071
#      20       -1.3142       -1.3191        766.1043
#      21       -1.3149       -1.3166        766.6466
#      22       -1.3173       -1.3284     +  764.5425
#      23       -1.3146       -1.3283        766.9380
#      24       -1.3159       -1.3158        766.0954
#      25       -1.3162       -1.3172        767.4745
#      26       -1.3169       -1.3171        765.5043
#      27       -1.3170       -1.3241        765.6597
#      28       -1.3178       -1.3204        765.4872
#      29       -1.3170       -1.3192        370.3340
#      30       -1.3172       -1.3197        345.0171
#      31       -1.3161       -1.3179        345.8363
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# zs-multi-mnist/GridedCCP_varyingk_circular/k15/run_4 | best epoch: 22 | train loss: -1.3173 | valid loss: -1.3284 | test log likelihood: 1.161
# submitit INFO (2019-11-09 23:23:26,738) - Job completed successfully
#
# submitit INFO (2019-11-09 17:01:27,920) - Starting with JobEnvironment(job_id=20002512_22, hostname=learnfair0744, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-09 17:01:27,920) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20002512_22/20002512_22_submitted.pkl
#
# --- Training zs-multi-mnist/GridedCCP_varyingk_circular/k15/run_5 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1       -1.2134       -1.2545     +  767.4426
#       2       -1.2613       -1.2775     +  767.3171
#       3       -1.2746       -1.2787     +  766.8767
#       4       -1.2863       -1.2912     +  766.4032
#       5       -1.2932       -1.2910        766.3096
#       6       -1.3014       -1.3111     +  766.7373
#       7       -1.3050       -1.2969        766.4841
#       8       -1.3056       -1.3101        766.2104
#       9       -1.3059       -1.3042        765.9085
#      10       -1.3105       -1.3098        766.7484
#      11       -1.3103       -1.3111     +  766.7517
#      12       -1.3091       -1.3147     +  764.5917
#      13       -1.3112       -1.3202     +  764.8217
#      14       -1.3120       -1.3086        766.3437
#      15       -1.3152       -1.3156        765.8486
#      16       -1.3123       -1.3184        766.2791
#      17       -1.3114       -1.3000        766.9464
#      18       -1.3120       -1.3254     +  767.1272
#      19       -1.3169       -1.3221        766.4139
#      20       -1.3148       -1.3150        766.1253
#      21       -1.3137       -1.3196        766.6687
#      22       -1.3163       -1.3195        764.3862
#      23       -1.3145       -1.3108        767.0109
#      24       -1.3149       -1.3175        766.1869
#      25       -1.3180       -1.3180        767.5656
#      26       -1.3165       -1.3202        765.6008
#      27       -1.3164       -1.3128        765.6333
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# zs-multi-mnist/GridedCCP_varyingk_circular/k15/run_5 | best epoch: 18 | train loss: -1.3152 | valid loss: -1.3254 | test log likelihood: 0.9982
# submitit INFO (2019-11-09 23:00:23,008) - Job completed successfully
#
# --------------------------------
# submitit INFO (2019-11-09 17:01:27,919) - Starting with JobEnvironment(job_id=20002512_23, hostname=learnfair0754, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-09 17:01:27,919) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20002512_23/20002512_23_submitted.pkl
#
# --- Training zs-multi-mnist/GridedCCP_varyingk_circular/k17/run_4 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1       -1.2126       -1.2468     +  884.8936
#       2       -1.2683       -1.2645     +  884.5069
#       3       -1.2774       -1.2914     +  885.2414
#       4       -1.2869       -1.2980     +  884.2271
#       5       -1.2964       -1.2952        883.5559
#       6       -1.3059       -1.3080     +  884.5234
#       7       -1.3060       -1.3068        885.0070
#       8       -1.3080       -1.3006        884.6817
#       9       -1.3105       -1.3138     +  883.5532
#      10       -1.3088       -1.3034        884.6932
#      11       -1.3108       -1.3120        884.7876
#      12       -1.3138       -1.3126        884.7394
#      13       -1.3125       -1.3154     +  885.0718
#      14       -1.3134       -1.3097        884.7513
#      15       -1.3147       -1.3193     +  884.0289
#      16       -1.3151       -1.3214     +  884.3986
#      17       -1.3131       -1.3115        883.6955
#      18       -1.3151       -1.3117        885.2171
#      19       -1.3155       -1.3173        885.5527
#      20       -1.3143       -1.3192        884.9335
#      21       -1.3153       -1.3167        884.8639
#      22       -1.3178       -1.3288     +  885.1968
#      23       -1.3156       -1.3285        884.3497
#      24       -1.3157       -1.3166        883.8577
#      25       -1.3166       -1.3177        884.4939
#      26       -1.3175       -1.3182        885.3711
#      27       -1.3171       -1.3242        884.1721
#      28       -1.3183       -1.3211        884.5423
#
# submitit INFO (2019-11-09 17:01:27,919) - Starting with JobEnvironment(job_id=20002512_23, hostname=learnfair0754, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-09 17:01:27,919) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20002512_23/20002512_23_submitted.pkl
#
# --- Training zs-multi-mnist/GridedCCP_varyingk_circular/k17/run_5 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1       -1.2171       -1.2584     +  884.9378
#       2       -1.2638       -1.2802     +  884.5292
#       3       -1.2785       -1.2903     +  885.3620
#       4       -1.2910       -1.2959     +  884.6066
#       5       -1.2972       -1.2946        884.0345
#       6       -1.3035       -1.3139     +  884.4936
#       7       -1.3070       -1.3010        884.9063
#       8       -1.3065       -1.3135        884.3763
#       9       -1.3077       -1.3058        884.1211
#      10       -1.3093       -1.3121        884.4489
#      11       -1.3118       -1.3115        884.5988
#      12       -1.3104       -1.3157     +  884.5759
#      13       -1.3118       -1.3193     +  884.7049
#      14       -1.3127       -1.3109        884.7604
#      15       -1.3162       -1.3171        884.0954
#      16       -1.3132       -1.3189        884.4059
#      17       -1.3123       -1.3019        883.9815
#      18       -1.3122       -1.3249     +  885.0399
#      19       -1.3172       -1.3225        885.4435
#      20       -1.3154       -1.3160        884.8582
#      21       -1.3089       -1.3194        885.0394
#      22       -1.3163       -1.3204        885.2041
#      23       -1.3151       -1.3111        884.0715
#      24       -1.3150       -1.3176        883.9984
#      25       -1.3181       -1.3175        884.6697
#      26       -1.3168       -1.3199        885.4035
#      27       -1.3168       -1.3145        884.3609
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# zs-multi-mnist/GridedCCP_varyingk_circular/k17/run_5 | best epoch: 18 | train loss: -1.3162 | valid loss: -1.3249 | test log likelihood: 1.2051
# submitit INFO (2019-11-09 23:55:40,694) - Job completed successfully

# %%
for j in job_64_ccp:
    print("--------------------------------")
    print(j.stderr())
# Out:
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
#
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
#
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
#
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
#
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
#
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
#
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
#
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
#
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
#
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
#
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
#
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
#
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
#
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
#
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
#
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
#
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None

# %%
for j in job_64_ccp:
    j.cancel()

# %%
11 + 7//2 * 5 * 2
# Out:
# 41

# %%
11 + (2 * 7//2 * 5)
# Out:
# 46

# %%
import seaborn as sns
import pandas as pd
from glob import glob
import numpy as np

dfs = []
prfx = "results/iclr-rebuttals/zs-mnist/GridedCCP_varyingk_circular/k"
for g in glob(f"{prfx}*/run*/eval.csv"):
    test_loglike = np.loadtxt(g, delimiter=",").mean()
    sffx = g[len(prfx):]
    splitted = sffx.split("/")
    kernel = int(splitted[0])
    receptive_field = 11 + (kernel//2 * 5 *2)
    run = int(splitted[1][len("run_"):])
    dfs.append([receptive_field,run,test_loglike])
    
    
df = pd.DataFrame(dfs,columns=["Size of Receptive Field","run","Test Log Likelihood"])

# %%
# %autosave 600
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# CENTER PLOTS
from IPython.core.display import HTML
display(HTML(""" <style> .output_png {display: table-cell; text-align: center; margin:auto; }
.prompt display:none;}  </style>"""))
  
import sys
sys.path.append("notebooks")

import numpy as np
import matplotlib.pyplot as plt
import torch
# Out:
# Autosaving every 600 seconds
#  <style> .output_png {display: table-cell; text-align: center; margin:auto; }
# .prompt display:none;}  </style>

# %%
plt.rcParams.update({"font.size": 14})
fig, ax = plt.subplots(1,1,figsize=(17,10))
ax.axvline(56, ls='--', color="tab:red", alpha=0.5, label="Size of Image")
ax.axvline(66, ls='--', color="tab:green", alpha=0.5, label="Size of Image + Padding")
sns.lineplot(x="Size of Receptive Field", y="Test Log Likelihood", data=df, ax=ax, label="Zero Shot Translated MNIST\n with Revert Padding")
sns.despine()

# %%
import seaborn as sns
import pandas as pd
from glob import glob
import numpy as np

dfs_zs_mmnist = []
prfx = "results/iclr-rebuttals/zs-mnist/GridedCCP_varyingk/k"
for g in glob(f"{prfx}*/run*/eval.csv"):
    test_loglike = np.loadtxt(g, delimiter=",").mean()
    sffx = g[len(prfx):]
    splitted = sffx.split("/")
    kernel = int(splitted[0])
    receptive_field = 11 + (kernel//2 * 5 *2)
    run = int(splitted[1][len("run_"):])
    dfs_zs_mmnist.append(["Zeros",receptive_field,run,test_loglike])
    
dfs_zs_mmnist_refl = []
prfx = "results/iclr-rebuttals/zs-mnist/GridedCCP_varyingk_circular/k"
for g in glob(f"{prfx}*/run*/eval.csv"):
    test_loglike = np.loadtxt(g, delimiter=",").mean()
    sffx = g[len(prfx):]
    splitted = sffx.split("/")
    kernel = int(splitted[0])
    receptive_field = 11 + (kernel//2 * 5 *2)
    run = int(splitted[1][len("run_"):])
    dfs_zs_mmnist_refl.append(["Circular", receptive_field,run,test_loglike])
    
    
    
dfs_zs_mmnist = pd.DataFrame(dfs_zs_mmnist,columns=["Padding","Size of Receptive Field","run","Test Log Likelihood"])
dfs_zs_mmnist_refl = pd.DataFrame(dfs_zs_mmnist_refl,columns=["Padding","Size of Receptive Field","run","Test Log Likelihood"])

df = pd.concat([dfs_zs_mmnist, dfs_zs_mmnist_refl])

plt.rcParams.update({"font.size": 14})
fig, ax = plt.subplots(1,1,figsize=(17,10))
ax.axvline(56, ls='--', color="tab:red", alpha=0.5, label="Size of Image")
ax.axvline(66, ls='--', color="tab:green", alpha=0.5, label="Size of Image + Padding")
sns.lineplot(x="Size of Receptive Field", y="Test Log Likelihood", hue="Padding", data=df, ax=ax)
sns.despine()

# %%
ls results/iclr-rebuttals/zs-multi-mnist/
# Out:
# GridedCCP_varyingk/
