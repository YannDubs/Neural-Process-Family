# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# # NeurIPS - Run Debug
#
# Goal : understand issues with ConvLNP
#
# Data : MNIST
#
# Models : SelfAttnLNP and ConvLNPXL and ConvCNPXL
#
# Loss : NLLLloss and CNPF
#
# Runs : 5

# %%
import os

os.chdir("..")

# %%
import neuralproc

# %%
import submitit

from train_imgs import main, parse_arguments

log_folder = "logs/%j"

# %%
def repeat_list(l, n):
    return [i for i in l for _ in range(n)]

class Run:
    def checkpoint(self, args):
        """Resubmits the same callable with the same arguments but makes sure continnue from last chckpnt."""
        args.is_continue_train = True
        return submitit.utils.DelayedSubmission(self, args)

    def __call__(self, args):
        job_env = submitit.utils.JobEnvironment()
        args.starting_run = args.starting_run * job_env.num_tasks + job_env.local_rank
        return main(args)

# %%
global_kwargs = "--max-epochs 50 --n-z-samples 16 --is-progressbar"
n_runs = 3 # 5

kwargs = [
          ("minsig_ConvNPFXL", "ConvNPF", "NllLNPF","--n-blocks 7 --kernel-size 9 --init-kernel-size 11 --n-conv-layers 2 --batch-size 32 --min-sigma 0.1"),
           ("minsig_SelfAttnNPF", "SelfAttnNPF", "NllLNPF", "--batch-size 32 --min-sigma 0.1"),
          ("homosked_SelfAttnNPF", "SelfAttnNPF", "NllLNPF", "--batch-size 32 --is-change-sked"),
          ("heterosked_ConvNPFXL", "ConvNPF", "NllLNPF","--n-blocks 7 --kernel-size 9 --init-kernel-size 11 --n-conv-layers 2 --batch-size 32 --is-change-sked"),
         ("both_ConvNPFXL", "ConvNPF", "NllLNPF","--n-blocks 7 --kernel-size 9 --init-kernel-size 11 --n-conv-layers 2 --batch-size 32 --is-both-paths"),
         ("global_ConvNPFXL", "ConvNPF", "NllLNPF","--n-blocks 7 --kernel-size 9 --init-kernel-size 11 --n-conv-layers 2 --batch-size 32 --is-global"),
    ("convnlp_ConvNPFXL", "ConvNPF", "CNPF","--n-blocks 7 --kernel-size 9 --init-kernel-size 11 --n-conv-layers 2 --batch-size 32 --is-convlnp-arch")
          ]

args = [parse_arguments(f"{model} {loss} {data} --starting-run {s} --name {name}_{loss} --chckpnt-dirname results/neurips/debug/ {global_kwargs} {other}".split())
            for s in range(n_runs)
            for data in ["mnist"]
            for name,model,loss,other in kwargs]

# %%
executor=submitit.SlurmExecutor(folder=log_folder, max_num_timeout=3)
executor.update_parameters(num_gpus=1, 
                           time=60*24*2,  
                           cpus_per_task=10, 
                           mem='32GB',
                          partition="priority",
                           comment="neurips"
                          )

# %%
jobs = executor.map_array(Run(), args)

# %%
############################################################

# %%
jobs
# Out:
# [SlurmJob<job_id=26741186_0, task_id=0, state="COMPLETED">,
#  SlurmJob<job_id=26741186_1, task_id=0, state="COMPLETED">,
#  SlurmJob<job_id=26741186_2, task_id=0, state="COMPLETED">,
#  SlurmJob<job_id=26741186_3, task_id=0, state="COMPLETED">,
#  SlurmJob<job_id=26741186_4, task_id=0, state="COMPLETED">,
#  SlurmJob<job_id=26741186_5, task_id=0, state="COMPLETED">,
#  SlurmJob<job_id=26741186_6, task_id=0, state="FAILED">,
#  SlurmJob<job_id=26741186_7, task_id=0, state="COMPLETED">,
#  SlurmJob<job_id=26741186_8, task_id=0, state="COMPLETED">,
#  SlurmJob<job_id=26741186_9, task_id=0, state="COMPLETED">,
#  SlurmJob<job_id=26741186_10, task_id=0, state="COMPLETED">,
#  SlurmJob<job_id=26741186_11, task_id=0, state="COMPLETED">,
#  SlurmJob<job_id=26741186_12, task_id=0, state="COMPLETED">,
#  SlurmJob<job_id=26741186_13, task_id=0, state="FAILED">,
#  SlurmJob<job_id=26741186_14, task_id=0, state="COMPLETED">,
#  SlurmJob<job_id=26741186_15, task_id=0, state="COMPLETED">,
#  SlurmJob<job_id=26741186_16, task_id=0, state="COMPLETED">,
#  SlurmJob<job_id=26741186_17, task_id=0, state="COMPLETED">,
#  SlurmJob<job_id=26741186_18, task_id=0, state="COMPLETED">,
#  SlurmJob<job_id=26741186_19, task_id=0, state="COMPLETED">,
#  SlurmJob<job_id=26741186_20, task_id=0, state="FAILED">]

# %%
for job in jobs:
    print("--------------------------------")
    print(job.stdout())
# Out:
# --------------------------------
# submitit INFO (2020-05-23 14:38:48,170) - Starting with JobEnvironment(job_id=26741186_0, hostname=learnfair0617, local_rank=0(1), node=0(1), global_rank=0(1))
# submitit INFO (2020-05-23 14
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# mnist/minsig_SelfAttnNPF_NllLNPF/run_0 | best epoch: 31 | train loss: -1257.1884 | valid loss: -1283.3877 | test log likelihood: 1262.6891
# submitit INFO (2020-05-23 16:40:51,625) - Job completed successfully
#
# --------------------------------
# submitit INFO (2020-05-23 14:39:11,105) - Starting with JobEnvironment(job_id=26741186_2, hostname=learnfair0210, local_rank=0(1), node=0(1), global_rank=0(1))
# submitit INFO (2020-05-23 14:39:11,106) - Loading pickle: /private/home/yannd/projects/NPF/logs/26741186_2/26741186_2_submitted.pkl
#
# --- Training mnist/homosked_SelfAttnNPF_NllLNPF/run_0 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1     -390.4336     -749.8616     +  174.2963
#       2     -790.1018     -893.8077     +  173.0800
#       3     -911.8617     -999.3229     +  173.1250
#       4     -997.1804    -1067.6248     +  173.8412
#       5    -1054.9968    -1147.6223     +  174.1756
#       6    -1099.3059    -1143.8862        173.5754
#       7    -1138.1168    -1241.2782     +  174.0016
#       8    -1183.6688    -1252.4765     +  173.9306
#       9    -1204.7622    -1304.2476     +  172.0972
#      10    -1236.2492    -1246.6239        170.0398
#      11    -1265.1709    -1251.4280        170.0813
#      12    -1287.3478    -1405.5332     +  172.2913
#      13    -1292.0806    -1329.2804        173.0538
#      14    -1327.2074    -1401.7857        172.9220
#      15    -1364.1193    -1422.0833     +  172.6113
#      16    -1375.5956    -1229.6843        172.4015
#      17    -1410.0190    -1377.8726        173.5726
#      18    -1387.4087    -1389.2785        171.4433
#      19    -1421.0423    -1499.7852     +  173.2083
#      20    -1407.2938    -1459.9254        171.8096
#      21    -1425.3951    -1534.0342     +  172.7834
#      22    -1480.2009    -1525.8208        174.4405
#      23    -1443.5572    -1464.5974        172.1539
#      24    -1450.3912    -1420.3073        171.8017
#      25    -1444.6065    -1577.9196     +  172.2703
#      26    -1485.6788    -1517.5045        172.2104
#      27    -1496.7395    -1544.4839        172.5193
#      28    -1509.1287    -1371.6466        173.8161
#      29    -1507.7653    -1528.9887        173.0833
#      30    -1504.7995    -1508.4580        172.0265
#      31    -1519.1221    -1672.1042     +  172.9961
#      32    -1520.3837    -1523.0986        173.2599
#      33    -1536.9212    -1615.0579        172.7997
#      34    -1536.5368    -1597.2225        172.9374
#      35    -1545.3844    -1576.0248        172.9751
#      36    -1515.6247    -1653.0625        171.9923
#      37    -1547.8000    -1547.7536        173.1802
#      38    -1580.4580    -1535.8697        173.2955
#      39    -1571.5449    -1393.2093        174.0509
#      40    -1568.2647    -1604.8248        172.5032
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# mnist/homosked_SelfAttnNPF_NllLNPF/run_0 | best epoch: 31 | train loss: -1519.1221 | valid loss: -1672.1042 | test log likelihood: 1593.6786
# submitit INFO (2020-05-23 16:38:04,078) - Job completed successfully
#
# --------------------------------
# submitit INFO (2020-05-23 14:39:09,360) - Starting with JobEnvironment(job_id=26741186_3, hostname=learnfair0225, local_rank=0(1), node=0(1), global_rank=0(1))
# submitit INFO (2020-05-23 14:39:09,361) - Loading pickle: /private/home/yannd/projects/NPF/logs/26741186_3/26741186_3_submitted.pkl
#
# --- Training mnist/heterosked_ConvNPFXL_NllLNPF/run_0 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       
---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1     -397.8670     -683.1015     +  178.6510
#       2     -773.8769     -939.4555     +  176.4367
#       3     -904.1702     -929.5144        176.0034
#       4    -1004.1466     -954.5775     +  177.5648
#       5    -1062.2161    -1138.4808     +  178.3697
#       6    -1101.9890    -1142.3490     +  177.8352
#       7    -1144.2879    -1185.4136     +  177.7955
#       8    -1189.3796    -1106.7933        178.5510
#       9    -1208.7458    -1264.3370     +  177.5475
#      10    -1252.7944    -1232.8220        178.8303
#      11    -1251.6815    -1322.8644     +  177.4093
#      12    -1309.6668    -1344.6138     +  177.5686
#      13    -1322.6780    -1332.3806        177.9822
#      14    -1321.1148    -1363.5701     +  177.1877
#      15    -1350.3474    -1419.8462     +  177.6053
#      16    -1368.7950    -1381.3592        177.1462
#      17    -1404.6023    -1414.6914        178.4585
#      18    -1372.2583    -1424.2262     +  176.9896
#      19    -1398.7990    -1470.5750     +  177.1986
#      20    -1428.5933    -1428.5263        177.7172
#      21    -1410.3598    -1365.9562        176.6105
#      22    -1455.9517    -1514.9182     +  178.3628
#      23    -1456.9444    -1520.5932     +  177.7961
#      24    -1454.1487    -1478.0036        177.8442
#      25    -1464.9216    -1477.1380        178.0084
#      26    -1486.4775    -1511.0398        177.2299
#      27    -1480.6704    -1617.0275     +  177.5571
#      28    -1504.6326    -1542.3339        178.2999
#      29    -1507.2176    -1569.5023        178.3528
#      30    -1520.8713    -1516.4047        178.2632
#      31    -1538.9372    -1512.8488        178.1966
#      32    -1489.9407    -1616.6490        175.7725
#      33    -1547.5190    -1560.0390        178.7043
#      34    -1545.5306    -1590.6969        177.2344
#      35    -1544.0457    -1562.3116        177.6570
#      36    -1534.9828    -1600.9001        177.3221
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# mnist/homosked_SelfAttnNPF_NllLNPF/run_2 | best epoch: 27 | train loss: -1486.4775 | valid loss: -1617.0275 | test log likelihood: 1555.071
# submitit INFO (2020-05-23 16:29:34,533) - Job completed successfully
#
# --------------------------------
# submitit INFO (2020-05-23 14:39:08,744) - Starting with JobEnvironment(job_id=26741186_17, hostname=learnfair0427, local_rank=0(1), node=0(1), global_rank=0(1))
# submitit INFO (2020-05-23 14:39:08,745) - Loading pickle: /private/home/yannd/projects/NPF/logs/26741186_17/26741186_17_submitted.pkl
#
# --- Training mnist/heterosked_ConvNPFXL_NllLNPF/run_2 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1    -1705.3570    -2370.0630     +  716.5304
#       2    -2467.7898    -2676.8658     +  717.3284
#       3    -2627.8465    -2668.6771        715.4848
#       4    -2715.9214    -2791.7743     +  715.1560
#       5    -1636.6860    -2605.7361        713.6014
#       6    -2644.1491    -2708.0047        712.9357
#       7    -2765.5024    -2870.7419     +  712.8855
#       8    -2761.0073     1015.1045        713.0356
#       9    -2693.2937    -2909.3925     +  713.0966
#      10    -2827.4259    -2810.9314        713.5801
#      11    -2801.2693    -2911.1323     +  713.3227
#      12    -2889.2428    -2879.1920        713.6261
#      13    -2893.4883    -2950.4189     +  713.5218
#      14    -2823.2215    -2888.4981        712.9269
#      15    -2912.1716    -3003.2294     +  712.6317
#      16    -2936.8516    -2944.2568        712.9076
#
# --------------------------------
# submitit INFO (2020-05-23 14:39:11,125) - Starting with JobEnvironment(job_id=26741186_18, hostname=learnfair0429, local_rank=0(1), node=0(1), global_rank=0(1))
# submitit INFO (2020-05-23 14:39:11,125) - Loading pickle: /private/home/yannd/projects/NPF/logs/26741186_18/26741186_18_submitted.pkl
#
# --- Training mnist/both_ConvNPFXL_NllLNPF/run_2 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1    -1044.8373    -1387.4934     +  724.1144
#       2    -1423.9138    -1563.8287     +  724.0886
#       3    -1538.4708    -1547.7093        724.3132
#       4    -1645.2680    -1646.2661     +  723.8601
#       5    -1680.3843    -1730.1007     +  723.6743
#       6    -1736.0151    -1730.5054     +  723.9481
#       7    -1749.0651    -1759.8324     +  723.6764
#       8    -1824.4941    -1802.3108     +  723.6256
#       9    -1826.7135    -1850.3640     +  723.8166
#      10    -1877.2803    -1881.2105     +  723.4551
#      11    -1867.4581    -1928.7871     +  723.6591
#      12    -1919.0822    -1933.1482     +  723.2996
#      13    -1923.3511    -1923.1750        723.3911
#      14    -1903.5561    -1933.8876     +  722.7688
#      15    -1936.2862    -2022.7806     +  719.6042
#
# --------------------------------
# submitit INFO (2020-05-23 14:39:11,105) - Starting with JobEnvironment(job_id=26741186_19, hostname=learnfair0442, local_rank=0(1), node=0(1), global_rank=0(1))
# submitit INFO (2020-05-23 14:39:11,105) - Loading pickle: /private/home/yannd/projects/NPF/logs/26741186_19/26741186_19_submitted.pkl
#
# --- Training mnist/global_ConvNPFXL_NllLNPF/run_2 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1     -924.2721    -1309.1355     +  725.7745
#       2    -1362.3432    -1525.9606     +  722.8455
#       3    -1485.6155    -1466.4043        721.9274
#       4    -1603.9889    -1587.2247     +  721.9114
#       5    -1670.1196    -1832.2599     +  721.4590
#       6    -1703.3854    -1698.6217        721.0587
#       7    -1753.6527    -1821.4218        721.2300
#       8    -1818.4537    -1839.9190     +  721.1106
#       9    -1816.8760    -1864.8385     +  720.7394
#      10    -1863.7847    -1808.3881        720.7579
#      11    -1847.1003    -1953.8970     +  720.4785
#      12    -1911.4679    -1938.7689        720.6131
#      13    -1914.5968    -1978.9058     +  720.3189
#      14    -1898.1512    -1928.2113        720.0629
#      15    -1927.0608    -2020.2014     +  718.8254
#
# --------------------------------
# submitit INFO (2020-05-23 14:39:11,105) - Starting with JobEnvironment(job_id=26741186_20, hostname=learnfair0442, local_rank=0(1), node=0(1), global_rank=0(1))
# submitit INFO (2020-05-23 14:39:11,105) - Loading pickle: /private/home/yannd/projects/NPF/logs/26741186_20/26741186_20_submitted.pkl
#
# --- Training mnist/convnlp_ConvNPFXL_CNPF/run_2 ---
#
# submitit ERROR (2020-05-23 14:39:20,541) - Submitted job triggered an exception

# %%
for job in jobs:
    print("--------------------------------")
    print(job.stderr())
# Out:
# --------------------------------
#
# --------------------------------
#
# --------------------------------
# /private/home/yannd/projects/NPF/neuralproc/architectures/mlp.py:67: UserWarning: hidden_size=32 smaller than output=128 and input=128. Setting it to 128.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
#
# --------------------------------
#
# --------------------------------
#
# --------------------------------
#
# --------------------------------
#
# --------------------------------
# /private/home/yannd/projects/NPF/neuralproc/architectures/mlp.py:67: UserWarning: hidden_size=32 smaller than output=128 and input=128. Setting it to 128.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
#
# --------------------------------
#
# --------------------------------
#
# --------------------------------
#
# --------------------------------
#
# --------------------------------
# /private/home/yannd/projects/NPF/neuralproc/architectures/mlp.py:67: UserWarning: hidden_size=32 smaller than output=128 and input=128. Setting it to 128.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
#
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None

# %%
for job in jobs:
    job.cancel()
