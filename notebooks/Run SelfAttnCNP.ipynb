# %% [markdown]
# # Run SelfAttnCNP

# %%
cd ..
# Out:
# /private/home/yannd/projects/Neural-Process-Family

# %%
import neuralproc

# %%
import submitit
from train_imgs import main, parse_arguments

log_folder="logs/%j"

# %%
def repeat_list(l, n):
    return [i for i in l for _ in range(n)]

class Run:
    def checkpoint(self, args):
        """Resubmits the same callable with the same arguments but makes sure continnue from last chckpnt."""
        args.is_continue_train=True 
        return submitit.utils.DelayedSubmission(self, args)
    
    def __call__(self, args):
        job_env = submitit.utils.JobEnvironment()
        args.starting_run = args.starting_run * job_env.num_tasks + job_env.local_rank
        return main(args)

# %%
datasets = ["celeba32", "celeba64", "svhn", "mnist", "zs-multi-mnist"]

args = [parse_arguments("{} {} --starting-run {} --batch-size 2".format(m, d, s).split())
        for s in range(6)
        for m in ["SelfAttnCNP"] 
        for d in ["zs-multi-mnist"]]

# %%
executor=submitit.SlurmExecutor(folder=log_folder, max_num_timeout=3)
executor.update_parameters(num_gpus=1, 
                           time=60*24*3, 
                           #partition="dev", 
                           cpus_per_task=10, 
                           mem='32GB',
                           constraint="volta32gb")

# %%
job = executor.map_array(Run(), args)

# %%
j = job[0]
job
# Out:
# [SlurmJob<job_id=17771085_0, task_id=0, state="FAILED">,
#  SlurmJob<job_id=17771085_1, task_id=0, state="FAILED">,
#  SlurmJob<job_id=17771085_2, task_id=0, state="FAILED">,
#  SlurmJob<job_id=17771085_3, task_id=0, state="FAILED">,
#  SlurmJob<job_id=17771085_4, task_id=0, state="FAILED">,
#  SlurmJob<job_id=17771085_5, task_id=0, state="FAILED">]

# %%
for j in job:
    print("--------------------------------")
    print(j.stdout())
# Out:
# --------------------------------
# submitit INFO (2019-09-17 05:36:10,652) - Starting with JobEnvironment(job_id=17771085_0, hostname=learnfair1212, local_rank=0(1), node=0(1), global_rank=0(1))
# submitit INFO (2019-09-17 05:36:10,652) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/17771085_0/17771085_0_submitted.pkl
#
# --- Training zs-multi-mnist/SelfAttnCNP/run_0 ---
#
# submitit ERROR (2019-09-17 06:17:25,573) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-09-17 05:36:10,652) - Starting with JobEnvironment(job_id=17771085_1, hostname=learnfair1215, local_rank=0(1), node=0(1), global_rank=0(1))
# submitit INFO (2019-09-17 05:36:10,652) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/17771085_1/17771085_1_submitted.pkl
#
# --- Training zs-multi-mnist/SelfAttnCNP/run_1 ---
#
# submitit ERROR (2019-09-17 06:18:11,243) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-09-17 05:36:10,652) - Starting with JobEnvironment(job_id=17771085_2, hostname=learnfair1215, local_rank=0(1), node=0(1), global_rank=0(1))
# submitit INFO (2019-09-17 05:36:10,652) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/17771085_2/17771085_2_submitted.pkl
#
# --- Training zs-multi-mnist/SelfAttnCNP/run_2 ---
#
# submitit ERROR (2019-09-17 06:17:02,003) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-09-17 05:36:10,652) - Starting with JobEnvironment(job_id=17771085_3, hostname=learnfair1215, local_rank=0(1), node=0(1), global_rank=0(1))
# submitit INFO (2019-09-17 05:36:10,652) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/17771085_3/17771085_3_submitted.pkl
#
# --- Training zs-multi-mnist/SelfAttnCNP/run_3 ---
#
# submitit ERROR (2019-09-17 06:16:23,790) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-09-17 05:36:10,652) - Starting with JobEnvironment(job_id=17771085_4, hostname=learnfair1229, local_rank=0(1), node=0(1), global_rank=0(1))
# submitit INFO (2019-09-17 05:36:10,653) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/17771085_4/17771085_4_submitted.pkl
#
# --- Training zs-multi-mnist/SelfAttnCNP/run_4 ---
#
# submitit ERROR (2019-09-17 06:18:18,389) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-09-17 05:36:10,827) - Starting with JobEnvironment(job_id=17771085_5, hostname=learnfair1240, local_rank=0(1), node=0(1), global_rank=0(1))
# submitit INFO (2019-09-17 05:36:10,827) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/17771085_5/17771085_5_submitted.pkl
#
# --- Training zs-multi-mnist/SelfAttnCNP/run_5 ---
#
# submitit ERROR (2019-09-17 06:18:01,889) - Submitted job triggered an exception

# %%
for j in job:
    print("--------------------------------")
    print(j.stderr())
# Out:
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:67: UserWarning: hidden_size=32 smaller than output=128 and input=128. Setting it to 128.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:67: UserWarning: hidden_size=32 smaller than output=256 and input=128. Setting it to 128.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# submitit ERROR (2019-09-17 06:17:25,573) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/_submit.py", line 6, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-21e536907d9e>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 263, in main
#     patience=args.patience,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 231, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 852, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 811, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 759, in fit_loop
#     step = self.validation_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 581, in validation_step
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 978, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 295, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 480, in deterministic_path
#     R_attn = self.attender(keys, queries, values, **attender_kwargs)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 555, in forward
#     context = super().forward(keys, queries, values, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 477, in forward
#     context = self.dot(keys, queries, values)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 147, in forward
#     attn = self.logits_to_attn(logits)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 163, in logits_to_attn
#     attn = logits.softmax(dim=-1)
# RuntimeError: CUDA out of memory. Tried to allocate 10.03 GiB (GPU 0; 31.72 GiB total capacity; 20.65 GiB already allocated; 9.49 GiB free; 564.91 MiB cached)
# srun: error: learnfair1212: task 0: Exited with exit code 1
#
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:67: UserWarning: hidden_size=32 smaller than output=128 and input=128. Setting it to 128.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:67: UserWarning: hidden_size=32 smaller than output=256 and input=128. Setting it to 128.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# submitit ERROR (2019-09-17 06:18:11,243) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/_submit.py", line 6, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-21e536907d9e>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 263, in main
#     patience=args.patience,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 231, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 852, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 811, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 759, in fit_loop
#     step = self.validation_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 581, in validation_step
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 978, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 295, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 480, in deterministic_path
#     R_attn = self.attender(keys, queries, values, **attender_kwargs)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 555, in forward
#     context = super().forward(keys, queries, values, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 477, in forward
#     context = self.dot(keys, queries, values)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 145, in forward
#     logits = self.score(keys, queries, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 219, in score
#     logits = logits / math.sqrt(kq_size)
# RuntimeError: CUDA out of memory. Tried to allocate 18.32 GiB (GPU 0; 31.72 GiB total capacity; 19.09 GiB already allocated; 10.93 GiB free; 689.86 MiB cached)
# srun: error: learnfair1215: task 0: Exited with exit code 1
#
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:67: UserWarning: hidden_size=32 smaller than output=128 and input=128. Setting it to 128.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:67: UserWarning: hidden_size=32 smaller than output=256 and input=128. Setting it to 128.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# submitit ERROR (2019-09-17 06:17:02,003) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/_submit.py", line 6, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-21e536907d9e>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 263, in main
#     patience=args.patience,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 231, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 852, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 811, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 759, in fit_loop
#     step = self.validation_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 581, in validation_step
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 978, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 295, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 480, in deterministic_path
#     R_attn = self.attender(keys, queries, values, **attender_kwargs)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 555, in forward
#     context = super().forward(keys, queries, values, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 477, in forward
#     context = self.dot(keys, queries, values)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 147, in forward
#     attn = self.logits_to_attn(logits)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 163, in logits_to_attn
#     attn = logits.softmax(dim=-1)
# RuntimeError: CUDA out of memory. Tried to allocate 13.90 GiB (GPU 0; 31.72 GiB total capacity; 28.48 GiB already allocated; 1.44 GiB free; 782.44 MiB cached)
# srun: error: learnfair1215: task 0: Exited with exit code 1
#
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:67: UserWarning: hidden_size=32 smaller than output=128 and input=128. Setting it to 128.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:67: UserWarning: hidden_size=32 smaller than output=256 and input=128. Setting it to 128.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# submitit ERROR (2019-09-17 06:16:23,790) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/_submit.py", line 6, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-21e536907d9e>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 263, in main
#     patience=args.patience,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 231, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 852, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 811, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 759, in fit_loop
#     step = self.validation_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 581, in validation_step
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 978, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 295, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 480, in deterministic_path
#     R_attn = self.attender(keys, queries, values, **attender_kwargs)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 555, in forward
#     context = super().forward(keys, queries, values, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 477, in forward
#     context = self.dot(keys, queries, values)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 147, in forward
#     attn = self.logits_to_attn(logits)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 163, in logits_to_attn
#     attn = logits.softmax(dim=-1)
# RuntimeError: CUDA out of memory. Tried to allocate 12.61 GiB (GPU 0; 31.72 GiB total capacity; 25.87 GiB already allocated; 4.63 GiB free; 191.79 MiB cached)
# srun: error: learnfair1215: task 0: Exited with exit code 1
#
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:67: UserWarning: hidden_size=32 smaller than output=128 and input=128. Setting it to 128.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:67: UserWarning: hidden_size=32 smaller than output=256 and input=128. Setting it to 128.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# submitit ERROR (2019-09-17 06:18:18,389) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/_submit.py", line 6, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-21e536907d9e>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 263, in main
#     patience=args.patience,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 231, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 852, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 811, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 759, in fit_loop
#     step = self.validation_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 581, in validation_step
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 978, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 295, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 480, in deterministic_path
#     R_attn = self.attender(keys, queries, values, **attender_kwargs)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 555, in forward
#     context = super().forward(keys, queries, values, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 477, in forward
#     context = self.dot(keys, queries, values)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 147, in forward
#     attn = self.logits_to_attn(logits)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 163, in logits_to_attn
#     attn = logits.softmax(dim=-1)
# RuntimeError: CUDA out of memory. Tried to allocate 10.67 GiB (GPU 0; 31.72 GiB total capacity; 21.96 GiB already allocated; 7.94 GiB free; 807.11 MiB cached)
# srun: error: learnfair1229: task 0: Exited with exit code 1
#
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:67: UserWarning: hidden_size=32 smaller than output=128 and input=128. Setting it to 128.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# /private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/mlp.py:67: UserWarning: hidden_size=32 smaller than output=256 and input=128. Setting it to 128.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
# submitit ERROR (2019-09-17 06:18:01,889) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/_submit.py", line 6, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/submitit/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-21e536907d9e>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 263, in main
#     patience=args.patience,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 231, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 852, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 811, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 759, in fit_loop
#     step = self.validation_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 581, in validation_step
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/skorch/net.py", line 978, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 285, in forward
#     z_sample, q_z_cntxt = self.latent_path(X_cntxt, Y_cntxt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 307, in latent_path
#     R_cntxt = self.xy_encoder(X_transf, Y)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/encoders.py", line 174, in forward
#     return self.flat_module(out)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/predefined/selfattn.py", line 89, in forward
#     out = attn_layer(out + add_to_keys, out, out)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 555, in forward
#     context = super().forward(keys, queries, values, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 477, in forward
#     context = self.dot(keys, queries, values)
#   File "/private/home/yannd/.conda/envs/neuralproc/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 147, in forward
#     attn = self.logits_to_attn(logits)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/utils/attention.py", line 163, in logits_to_attn
#     attn = logits.softmax(dim=-1)
# RuntimeError: CUDA out of memory. Tried to allocate 7.67 GiB (GPU 0; 31.72 GiB total capacity; 16.05 GiB already allocated; 6.85 GiB free; 7.79 GiB cached)
# srun: error: learnfair1240: task 0: Exited with exit code 1
