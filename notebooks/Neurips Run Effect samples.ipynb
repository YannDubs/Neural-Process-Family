# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# # NeurIPS - Run Log Like
#
# Goal : have a table that compares the log likelihood of the models
#
# Data : SVHN, CIFAR32 (MNIST Already Ran in Losses)
#
# Models : SelfAttnLNP and ConvLNPXL and ConvCNPXL
#
# Loss : NLLLloss and CNPF
#
# Runs : 5

# %%
import os

os.chdir("..")

import submitit

from train_imgs import main, parse_arguments
from results import get_exp_args

class Run:
    def checkpoint(self, args):
        """Resubmits the same callable with the same arguments but makes sure continnue from last chckpnt."""
        args.is_continue_train = True
        return submitit.utils.DelayedSubmission(self, args)

    def __call__(self, args):
        job_env = submitit.utils.JobEnvironment()
        args.starting_run = args.starting_run * job_env.num_tasks + job_env.local_rank
        return main(args)

# %%
args = get_exp_args("exp_loglike_isglobal", is_load=False)
len(args)

# %%
executor=submitit.SlurmExecutor(folder="logs/%j", max_num_timeout=3)
executor.update_parameters(num_gpus=1, 
                           time=60*24,  
                           cpus_per_task=10, 
                           mem='32GB',
                          partition="priority",
                           comment="neurips"
                          )

# %%
jobs = executor.map_array(Run(), args)

# %%
############################################################

# %%
jobs
# Out:
# [SlurmJob<job_id=27001980_0, task_id=0, state="UNKNOWN">,
#  SlurmJob<job_id=27001980_1, task_id=0, state="UNKNOWN">,
#  SlurmJob<job_id=27001980_2, task_id=0, state="UNKNOWN">,
#  SlurmJob<job_id=27001980_3, task_id=0, state="UNKNOWN">,
#  SlurmJob<job_id=27001980_4, task_id=0, state="UNKNOWN">,
#  SlurmJob<job_id=27001980_5, task_id=0, state="UNKNOWN">,
#  SlurmJob<job_id=27001980_6, task_id=0, state="UNKNOWN">,
#  SlurmJob<job_id=27001980_7, task_id=0, state="UNKNOWN">,
#  SlurmJob<job_id=27001980_8, task_id=0, state="UNKNOWN">,
#  SlurmJob<job_id=27001980_9, task_id=0, state="UNKNOWN">]

# %%
for job in jobs:
    print("--------------------------------")
    print(job.stdout())
# Out:
# --------------------------------
# submitit INFO (2020-05-27 17:22:02,172) - Starting with JobEnvironment(job_id=26921719_0, hostname=learnfair4072, local_rank=0(1), node=0(1), global_rank=0(1))
# submitit INFO (2020-05-27 17:22:02,172) - Loading pickle: /private/home/yannd/projects/NPF/logs/26921719_0/26921719_0_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/data/test_32x32.mat
#
# --- Training svhn/ConvNPFXL_NllLNPF/run_0 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1    -3148.7470    -3519.7704     +  626.9017
#       2    -3546.2664    -3676.4107     +  626.5822
#       3    -3741.2965    -3811.1884     +  626.2631
#       4    -3673.1596    -3834.1199     +  625.1252
#       5    -3854.1319    -3886.2377     +  624.1915
#       6    -3766.1968    -3815.0661        623.3788
#       7    -3868.9867    -3917.7212     +  624.0479
#       8    -3734.7482    -3913.3524        620.4858
#       9    -3842.3210    -3885.3166        619.5745
#      10    -3918.3235    -3926.6254     +  621.0277
#      11    -3775.4868    -3940.4471     +  620.5273
#      12    -3940.6719    -3946.9760     +  620.7962
#      13    -3908.9796    -3954.2635     +  621.6967
#      14    -3910.6903    -3956.4088     +  619.8146
#      15    -3900.4610    -4011.1355     +  619.2920
#      16    -3894.1835    -3961.6349        620.0822
#      17    -3955.5168    -3954.1246        622.8927
#      18    -3948.2511    -4002.2993        622.1972
#      19    -3960.1535    -3967.0102        622.5034
#      20    -3936.4345    -3897.2134        623.7000
#      21    -3965.9793    -3970.4026        622.2822
#      22    -3975.0331    -3993.5307        622.7244
#      23    -3977.9631    -3965.0215        623.2521
#      24    -3975.1546    -4009.3584        623.9074
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# svhn/ConvNPFXL_NllLNPF/run_1 | best epoch: 38 | train loss: -4025.9165 | valid loss: -4069.9028 | test log likelihood: 4045.1709
# submitit INFO (2020-05-28 01:39:42,739) - Job completed successfully
#
# --------------------------------
# submitit INFO (2020-05-27 17:22:02,685) - Starting with JobEnvironment(job_id=26921719_2, hostname=learnfair4025, local_rank=0(1), node=0(1), global_rank=0(1))
# submitit INFO (2020-05-27 17:22:02,685) - Loading pickle: /private/home/yannd/projects/NPF/logs/26921719_2/26921719_2_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/data/test_32x32.mat
#
# --- Training svhn/ConvNPFXL_NllLNPF/run_2 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1    -3088.8849    -3373.1972     +  625.2403
#       2    -3613.4828    -3323.4014        626.8872
#       3    -3662.7968    -3829.0085     +  626.5578
#       4    -3615.1421    -3766.7318        626.2535
#       5    -3808.8794    -3836.4725     +  625.9009
#       6    -3773.5340    -3729.1829        625.8545
#       7    -3874.4339    -3926.2296     +  626.1672
#       8    -3808.9462    -3874.3100        625.2615
#       9    -3774.7796    -3937.7617     +  625.3561
#      10    -3908.7145    -3893.4036        626.1109
#      11    -3861.7531    -3854.6044        624.9554
#      12    -3881.9399    -3855.6383        625.2017
#      13    -3913.8093    -3967.0942     +  624.7625
#      14    -3832.5899    -3943.9823        623.2631
#      15    -3911.3158    -3946.1552        622.5192
#      16    -3896.6507    -3483.2422        622.4079
#      17    -3872.0748    -3815.4833        622.0499
#      18    -3895.5069    -4015.6001     +  623.9056
#      19    -3930.7351    -3966.2996        623.5149
#      20    -3971.6794    -4020.5187     +  624.0046
#      21    -3886.7790    -3936.7571        621.6564
#      22    -3944.1460    -4016.7316        621.1272
#      23    -3953.3203    -3968.8217        622.8964
#      24    -3967.2906    -4029.2698     +  622.4513
#      25    -3978.9972    -4032.0770     +  621.6551
#      26    -3949.9617    -3979.1582        621.4388
#      27    -3992.5418    -3927.0281        623.4134
#      28    -3994.4444    -4027.3697        623.6782
#      29    -3984.4822    -3975.5495        623.3657
#      30    -4014.4208    -3974.8092        624.2770
#      31    -4026.3235    -3986.1846        624.5837
#      32    -4003.2656    -4015.7194        624.4108
#      33    -4002.4762    -4025.2195        624.0959
#      34    -3969.8819    -3998.3438        623.9916
# Stopping since valid_loss has not improved in the last 10 epochs.
# Re-initializing module.
# Re-initializing optimizer.
# svhn/ConvNPFXL_NllLNPF/run_2 | best epoch: 25 | train loss: -3978.9972 | valid loss: -4032.077 | test log likelihood: 3992.8992
# submitit INFO (2020-05-27 23:29:01,249) - Job completed successfully
#
# --------------------------------
# submitit INFO (2020-05-27 17:22:02,304) - Starting with JobEnvironment(job_id=26921719_3, hostname=learnfair4080, local_rank=0(1), node=0(1), global_rank=0(1))
# submitit INFO (2020-05-27 17:22:02,304) - Loading pickle: /private/home/yannd/projects/NPF/logs/26921719_3/26921719_3_submitted.pkl
# Using downloaded and verified file: /private/home/yannd/data/train_32x32.mat
# Using downloaded and verified file: /private/home/yannd/data/test_32x32.mat
#
# --- Training svhn/ConvNPFXL_NllLNPF/run_3 ---
#
#   epoch    train_loss    valid_loss    cp       dur
# -------  ------------  ------------  ----  --------
#       1    -2968.5594    -3525.9356     +  631.9852
#       2    -3442.9235    -3055.6015        632.2562
#       3    -3718.2968    -3689.0309     +  632.5368
#       4    -3773.5854    -3855.0482     +  632.3973
#       5    -3796.6464    -3724.3028        631.9621
#       6    -3725.8746    -3863.8478     +  632.4072
#       7    -3788.8804    -3834.8856        632.6798
#       8    -3857.7521    -3825.5032        632.7119
#       9    -3746.4904    -3874.6693     +  632.3751
#      10    -3796.1409    -3674.7949        632.3004
#      11    -3865.1850    -3920.6944     +  632.0627
local_rank=0(1), node=0(1), global_rank=0(1))
# submitit INFO (2020-05-27 17:22:02,200) - Loading pickle: /private/home/yannd/projects/NPF/logs/26921719_6/26921719_6_submitted.pkl
#
# --- Training celeba32/ConvNPFXL_NllLNPF/run_1 ---
#
#   epoch    train_loss    valid_loss    cp        dur
# -------  ------------  ------------  ----  ---------
#       1    -2099.4913    -2621.4989     +  1882.4247
#       2    -2735.3382    -3003.9507     +  1630.8700
#       3    -2943.2654    -3070.0236     +  1630.2180
#       4    -3049.5901    -3167.0432     +  1626.3160
#       5    -3102.3604    -3208.4811     +  1626.0478
#       6    -3173.6947    -3215.5753     +  1625.4892
#       7    -3058.3505    -3055.6704        1626.5424
#       8    -3205.6342    -3082.9986        1626.2880
#       9    -3245.0115    -3259.9147     +  1626.3574
#      10    -3251.2496    -3258.4973        1626.5059
#      11    -3232.4475    -3098.0840        1626.7562
#      12    -3246.9655    -3313.3681     +  1628.6506
#      13    -3272.0443    -3379.9156     +  1628.8105
#      14    -3280.2263    -3255.6844        1628.6447
#      15    -3281.5272    -3379.7565        1628.5237
#      16    -3281.8470    -3365.6592        1627.0246
#      17    -3288.2453    -3326.4169        1627.9785
#      18    -3312.7563    -3330.2866        1628.2563
#      19    -3311.8104    -3304.6217        1630.7737
#
# --------------------------------
# submitit INFO (2020-05-27 17:22:02,210) - Starting with JobEnvironment(job_id=26921719_7, hostname=learnfair4033, local_rank=0(1), node=0(1), global_rank=0(1))
# submitit INFO (2020-05-27 17:22:02,210) - Loading pickle: /private/home/yannd/projects/NPF/logs/26921719_7/26921719_7_submitted.pkl
#
# --- Training celeba32/ConvNPFXL_NllLNPF/run_2 ---
#
#   epoch    train_loss    valid_loss    cp        dur
# -------  ------------  ------------  ----  ---------
#       1    -2067.1204    -2314.0848     +  1865.8882
#       2    -2569.9664    -2641.1359     +  1614.7199
#       3    -2783.5313    -3003.2252     +  1619.9777
#       4    -2914.4790    -2994.5770        1621.8873
#       5    -3020.0719    -3145.1766     +  1618.4744
#       6    -3080.3386    -3131.8519        1621.1920
#       7    -3118.5878    -3143.2049        1622.5550
#       8    -3177.6195    -3183.6317     +  1614.7045
#       9    -3206.8700    -3253.0264     +  1608.2776
#      10    -3231.9722    -3332.1557     +  1615.3478
#      11    -3243.9259    -3260.5196        1623.5235
#      12    -3276.1761    -3349.0047     +  1624.5557
#      13    -3281.7789    -3286.4672        1623.1320
#      14    -3293.2395    -3313.7588        1622.0248
#      15    -3280.8667    -3372.6565     +  1622.5172
#      16    -3289.2075    -3291.2452        1623.4894
#      17    -3278.6469    -3358.7320        1623.8929
#      18    -3300.3055    -3325.4756        1623.6095
#      19    -3297.4362    -3307.6936        1626.9237
#
# --------------------------------
# submitit INFO (2020-05-27 17:21:18,434) - Starting with JobEnvironment(job_id=26921719_8, hostname=learnfair4083, local_rank=0(1), node=0(1), global_rank=0(1))
# submitit INFO (2020-05-27 17:21:18,434) - Loading pickle: /private/home/yannd/projects/NPF/logs/26921719_8/26921719_8_submitted.pkl
#
# --- Training celeba32/ConvNPFXL_NllLNPF/run_3 ---
#
#   epoch    train_loss    valid_loss    cp        dur
# -------  ------------  ------------  ----  ---------
#       1    -2082.5982    -2758.8406     +  1852.0690
#       2    -2818.0388    -2855.1680     +  1693.8167
#       3    -2862.6081    -3004.3744     +  1688.1596
#       4    -2994.7830    -3023.1836     +  1682.6428
#       5    -3069.5401    -3057.1267     +  1691.5805
#       6    -3149.1601    -3256.0103     +  1693.4891
#       7    -3149.0491    -3193.7453        1704.6091
#       8    -3191.5377    -3218.5506        1700.1590
#       9    -3239.1491    -3240.7036        1693.7703
#      10    -3234.4057    -3299.4593     +  1695.1718
#      11    -3248.8989    -3302.2856     +  1693.0055
#      12    -3280.8137    -3222.8705        1698.4797
#      13    -3292.9308    -3322.3324     +  1724.0927
#      14    -3287.8191    -3361.4256     +  1696.8958
#      15    -3291.4596    -3380.0078     +  1694.5445
#      16    -3299.6971    -3325.5538        1684.6871
#      17    -3294.4033    -3309.4858        1680.0555
#      18    -3329.4432    -3350.6667        1687.7028
#      19    -3321.6345    -3296.3837        1702.7035
#
# --------------------------------
# submitit INFO (2020-05-27 17:22:01,982) - Starting with JobEnvironment(job_id=26921719_9, hostname=learnfair4083, local_rank=0(1), node=0(1), global_rank=0(1))
# submitit INFO (2020-05-27 17:22:01,982) - Loading pickle: /private/home/yannd/projects/NPF/logs/26921719_9/26921719_9_submitted.pkl
#
# --- Training celeba32/ConvNPFXL_NllLNPF/run_4 ---
#
#   epoch    train_loss    valid_loss    cp        dur
# -------  ------------  ------------  ----  ---------
#       1    -2157.6917    -1915.2104     +  1837.7332
#       2    -2764.9893    -2756.5508     +  1682.0323
#       3    -2889.5051    -2891.5232     +  1675.8199
#       4    -3047.2703    -3160.4516     +  1671.5073
#       5    -3068.5392    -3191.1943     +  1677.5007
#       6    -3164.4507    -3182.9013        1679.7586
#       7    -3160.1424    -3208.6959     +  1687.0176
#       8    -3199.2934    -3261.7811     +  1688.1526
#       9    -3222.0268    -3274.4934     +  1678.6624
#      10    -3259.7282    -3263.6263        1680.9468
#      11    -3271.6057    -3264.8454        1678.3017
#      12    -3274.9271    -3323.3610     +  1682.7804
#      13    -3286.2639    -3312.0357        1710.0801
#      14    -3297.8881    -3307.6854        1685.5362
#      15    -3291.9682    -3283.4232        1682.1917
#      16    -3319.2130    -3340.5322     +  1674.8343
#      17    -3316.5032    -3311.6618        1667.4857
#      18    -3312.2250    -3320.6927        1670.7342
#      19    -3326.8333    -3343.5980     +  1691.3289

# %%
for job in jobs:
    print("--------------------------------")
    print(job.stderr())
# Out:
# --------------------------------
#
# --------------------------------
#
# --------------------------------
# /private/home/yannd/projects/NPF/neuralproc/architectures/mlp.py:67: UserWarning: hidden_size=32 smaller than output=128 and input=128. Setting it to 128.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
#
# --------------------------------
#
# --------------------------------
#
# --------------------------------
#
# --------------------------------
#
# --------------------------------
# /private/home/yannd/projects/NPF/neuralproc/architectures/mlp.py:67: UserWarning: hidden_size=32 smaller than output=128 and input=128. Setting it to 128.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
#
# --------------------------------
#
# --------------------------------
#
# --------------------------------
#
# --------------------------------
#
# --------------------------------
# /private/home/yannd/projects/NPF/neuralproc/architectures/mlp.py:67: UserWarning: hidden_size=32 smaller than output=128 and input=128. Setting it to 128.
#   warnings.warn(txt.format(hidden_size, output_size, input_size, self.hidden_size))
#
# --------------------------------
#
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None
# --------------------------------
# None

# %%
for job in jobs:
    job.cancel()
