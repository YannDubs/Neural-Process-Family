# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# # Run GriddedCCP

# %%
cd ..
# Out:
# /private/home/yannd/projects/Neural-Process-Family

# %%
import neuralproc

# %%
import submitit
from train_imgs import main, parse_arguments

log_folder="logs/%j"

# %%
def repeat_list(l, n):
    return [i for i in l for _ in range(n)]

class Run:
    def checkpoint(self, args):
        """Resubmits the same callable with the same arguments but makes sure continnue from last chckpnt."""
        args.is_continue_train=True 
        return submitit.utils.DelayedSubmission(self, args)
    
    def __call__(self, args):
        job_env = submitit.core.utils.JobEnvironment()
        args.starting_run = args.starting_run * job_env.num_tasks + job_env.local_rank
        return main(args)

# %%
datasets_64 = ["zs-mnist"]

Grided_ccp_kwargs = [(f"GridedCCP_varyingk_nobias/k{kernel}", f"--n-blocks 5 --kernel-size {kernel} --init-kernel-size 11 --max-epochs 10 --is-no-bias")
                     for kernel in [1+2*i for i in range(1,9)]]

args_64_ccp = [parse_arguments("GridedCCP {} --starting-run {} --name {} --chckpnt-dirname results/iclr-rebuttals/ {}".format(d, s, name, other).split())
                for s in range(3)
                for d in datasets_64
                for name,other in Grided_ccp_kwargs]

# %%
executor_64_ccp=submitit.SlurmExecutor(folder=log_folder, max_num_timeout=3)
executor_64_ccp.update_parameters(num_gpus=1, 
                                   time=200,#60*24,  
                                   cpus_per_task=10, 
                                   mem='32GB',
                                   ntasks_per_node=2,
                                  )

# %%
job_64_ccp = executor_64_ccp.map_array(Run(), args_64_ccp)

# %%
############################################################

# %%
job_64_ccp
# Out:
# [SlurmJob<job_id=20038374_0, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20038374_1, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20038374_2, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20038374_3, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20038374_4, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20038374_5, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20038374_6, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20038374_7, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20038374_8, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20038374_9, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20038374_10, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20038374_11, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20038374_12, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20038374_13, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20038374_14, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20038374_15, task_id=None, state="RUNNING">,
#  SlurmJob<job_id=20038374_16, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20038374_17, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20038374_18, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20038374_19, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20038374_20, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20038374_21, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20038374_22, task_id=None, state="COMPLETED">,
#  SlurmJob<job_id=20038374_23, task_id=None, state="RUNNING">]

# %%
for j in job_64_ccp:
    print("--------------------------------")
    print(j.stdout())
# Out:
# --------------------------------
# submitit INFO (2019-11-10 19:17:22,870) - Starting with JobEnvironment(job_id=20038297_0, hostname=learnfair0398, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:17:22,870) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_0/20038297_0_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k3/run_0 ---
#
# submitit ERROR (2019-11-10 19:17:37,440) - Submitted job triggered an exception
#
# submitit INFO (2019-11-10 19:17:22,870) - Starting with JobEnvironment(job_id=20038297_0, hostname=learnfair0398, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:17:22,870) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_0/20038297_0_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k3/run_1 ---
#
# submitit ERROR (2019-11-10 19:17:37,441) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-11-10 19:17:22,850) - Starting with JobEnvironment(job_id=20038297_1, hostname=learnfair0402, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:17:22,851) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_1/20038297_1_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k5/run_0 ---
#
# submitit ERROR (2019-11-10 19:17:37,736) - Submitted job triggered an exception
#
# submitit INFO (2019-11-10 19:17:22,850) - Starting with JobEnvironment(job_id=20038297_1, hostname=learnfair0402, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:17:22,850) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_1/20038297_1_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k5/run_1 ---
#
# submitit ERROR (2019-11-10 19:17:37,738) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-11-10 19:17:22,829) - Starting with JobEnvironment(job_id=20038297_2, hostname=learnfair0405, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:17:22,829) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_2/20038297_2_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k7/run_0 ---
#
# submitit ERROR (2019-11-10 19:17:37,717) - Submitted job triggered an exception
#
# submitit INFO (2019-11-10 19:17:22,829) - Starting with JobEnvironment(job_id=20038297_2, hostname=learnfair0405, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:17:22,829) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_2/20038297_2_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k7/run_1 ---
#
# submitit ERROR (2019-11-10 19:17:37,462) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-11-10 19:17:43,581) - Starting with JobEnvironment(job_id=20038297_3, hostname=learnfair0398, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:17:43,581) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_3/20038297_3_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k9/run_0 ---
#
# submitit ERROR (2019-11-10 19:17:58,209) - Submitted job triggered an exception
#
# submitit INFO (2019-11-10 19:17:43,581) - Starting with JobEnvironment(job_id=20038297_3, hostname=learnfair0398, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:17:43,581) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_3/20038297_3_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k9/run_1 ---
#
# submitit ERROR (2019-11-10 19:17:58,207) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-11-10 19:17:43,580) - Starting with JobEnvironment(job_id=20038297_4, hostname=learnfair0402, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:17:43,581) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_4/20038297_4_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k11/run_0 ---
#
# submitit ERROR (2019-11-10 19:17:58,502) - Submitted job triggered an exception
#
# submitit INFO (2019-11-10 19:17:43,580) - Starting with JobEnvironment(job_id=20038297_4, hostname=learnfair0402, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:17:43,580) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_4/20038297_4_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k11/run_1 ---
#
# submitit ERROR (2019-11-10 19:17:58,503) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-11-10 19:17:43,605) - Starting with JobEnvironment(job_id=20038297_5, hostname=learnfair0405, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:17:43,605) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_5/20038297_5_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k13/run_0 ---
#
# submitit ERROR (2019-11-10 19:17:58,447) - Submitted job triggered an exception
#
# submitit INFO (2019-11-10 19:17:43,604) - Starting with JobEnvironment(job_id=20038297_5, hostname=learnfair0405, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:17:43,605) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_5/20038297_5_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k13/run_1 ---
#
# submitit ERROR (2019-11-10 19:17:58,037) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-11-10 19:17:43,617) - Starting with JobEnvironment(job_id=20038297_6, hostname=learnfair0411, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:17:43,617) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_6/20038297_6_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k15/run_0 ---
#
# submitit ERROR (2019-11-10 19:17:59,872) - Submitted job triggered an exception
#
# submitit INFO (2019-11-10 19:17:43,617) - Starting with JobEnvironment(job_id=20038297_6, hostname=learnfair0411, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:17:43,617) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_6/20038297_6_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k15/run_1 ---
#
# submitit ERROR (2019-11-10 19:17:59,871) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-11-10 19:17:43,604) - Starting with JobEnvironment(job_id=20038297_7, hostname=learnfair0417, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:17:43,604) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_7/20038297_7_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k17/run_0 ---
#
# submitit ERROR (2019-11-10 19:18:00,605) - Submitted job triggered an exception
#
# submitit INFO (2019-11-10 19:17:43,604) - Starting with JobEnvironment(job_id=20038297_7, hostname=learnfair0417, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:17:43,604) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_7/20038297_7_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k17/run_1 ---
#
# submitit ERROR (2019-11-10 19:18:00,745) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-11-10 19:17:43,604) - Starting with JobEnvironment(job_id=20038297_8, hostname=learnfair0417, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:17:43,604) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_8/20038297_8_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k3/run_2 ---
#
# submitit ERROR (2019-11-10 19:18:00,437) - Submitted job triggered an exception
#
# submitit INFO (2019-11-10 19:17:43,604) - Starting with JobEnvironment(job_id=20038297_8, hostname=learnfair0417, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:17:43,604) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_8/20038297_8_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k3/run_3 ---
#
# submitit ERROR (2019-11-10 19:18:00,396) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-11-10 19:17:43,604) - Starting with JobEnvironment(job_id=20038297_9, hostname=learnfair0417, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:17:43,604) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_9/20038297_9_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k5/run_2 ---
#
# submitit ERROR (2019-11-10 19:18:00,396) - Submitted job triggered an exception
#
# submitit INFO (2019-11-10 19:17:43,604) - Starting with JobEnvironment(job_id=20038297_9, hostname=learnfair0417, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:17:43,604) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_9/20038297_9_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k5/run_3 ---
#
# submitit ERROR (2019-11-10 19:18:00,394) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-11-10 19:17:48,011) - Starting with JobEnvironment(job_id=20038297_10, hostname=learnfair0423, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:17:48,011) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_10/20038297_10_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k7/run_2 ---
#
# submitit ERROR (2019-11-10 19:18:17,274) - Submitted job triggered an exception
#
# submitit INFO (2019-11-10 19:17:48,010) - Starting with JobEnvironment(job_id=20038297_10, hostname=learnfair0423, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:17:48,011) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_10/20038297_10_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k7/run_3 ---
#
# submitit ERROR (2019-11-10 19:18:17,269) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-11-10 19:18:52,806) - Starting with JobEnvironment(job_id=20038297_11, hostname=learnfair0509, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:18:52,806) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_11/20038297_11_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k9/run_2 ---
#
# submitit ERROR (2019-11-10 19:19:09,053) - Submitted job triggered an exception
#
# submitit INFO (2019-11-10 19:18:52,806) - Starting with JobEnvironment(job_id=20038297_11, hostname=learnfair0509, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:18:52,806) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_11/20038297_11_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k9/run_3 ---
#
# submitit ERROR (2019-11-10 19:19:09,050) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-11-10 19:18:52,806) - Starting with JobEnvironment(job_id=20038297_12, hostname=learnfair0509, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:18:52,807) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_12/20038297_12_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k11/run_2 ---
#
# submitit ERROR (2019-11-10 19:19:09,137) - Submitted job triggered an exception
#
# submitit INFO (2019-11-10 19:18:52,806) - Starting with JobEnvironment(job_id=20038297_12, hostname=learnfair0509, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:18:52,807) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_12/20038297_12_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k11/run_3 ---
#
# submitit ERROR (2019-11-10 19:19:09,088) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-11-10 19:18:52,772) - Starting with JobEnvironment(job_id=20038297_13, hostname=learnfair0398, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:18:52,772) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_13/20038297_13_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k13/run_2 ---
#
# submitit ERROR (2019-11-10 19:19:06,973) - Submitted job triggered an exception
#
# submitit INFO (2019-11-10 19:18:52,772) - Starting with JobEnvironment(job_id=20038297_13, hostname=learnfair0398, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:18:52,772) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_13/20038297_13_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k13/run_3 ---
#
# submitit ERROR (2019-11-10 19:19:06,972) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-11-10 19:18:52,772) - Starting with JobEnvironment(job_id=20038297_14, hostname=learnfair0402, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:18:52,772) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_14/20038297_14_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k15/run_2 ---
#
# submitit ERROR (2019-11-10 19:19:07,316) - Submitted job triggered an exception
#
# submitit INFO (2019-11-10 19:18:52,772) - Starting with JobEnvironment(job_id=20038297_14, hostname=learnfair0402, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:18:52,772) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_14/20038297_14_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k15/run_3 ---
#
# submitit ERROR (2019-11-10 19:19:07,224) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-11-10 19:18:52,776) - Starting with JobEnvironment(job_id=20038297_15, hostname=learnfair0405, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:18:52,777) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_15/20038297_15_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k17/run_2 ---
#
# submitit ERROR (2019-11-10 19:19:07,495) - Submitted job triggered an exception
#
# submitit INFO (2019-11-10 19:18:52,776) - Starting with JobEnvironment(job_id=20038297_15, hostname=learnfair0405, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:18:52,776) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_15/20038297_15_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k17/run_3 ---
#
# submitit ERROR (2019-11-10 19:19:06,966) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-11-10 19:18:53,008) - Starting with JobEnvironment(job_id=20038297_16, hostname=learnfair0411, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:18:53,008) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_16/20038297_16_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k3/run_4 ---
#
# submitit ERROR (2019-11-10 19:19:11,752) - Submitted job triggered an exception
#
# submitit INFO (2019-11-10 19:18:53,008) - Starting with JobEnvironment(job_id=20038297_16, hostname=learnfair0411, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:18:53,008) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_16/20038297_16_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k3/run_5 ---
#
# submitit ERROR (2019-11-10 19:19:11,637) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-11-10 19:18:52,867) - Starting with JobEnvironment(job_id=20038297_17, hostname=learnfair0417, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:18:52,867) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_17/20038297_17_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k5/run_4 ---
#
# submitit ERROR (2019-11-10 19:19:08,476) - Submitted job triggered an exception
#
# submitit INFO (2019-11-10 19:18:52,867) - Starting with JobEnvironment(job_id=20038297_17, hostname=learnfair0417, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:18:52,867) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_17/20038297_17_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k5/run_5 ---
#
# submitit ERROR (2019-11-10 19:19:08,612) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-11-10 19:18:59,981) - Starting with JobEnvironment(job_id=20038297_18, hostname=learnfair0417, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:18:59,981) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_18/20038297_18_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k7/run_4 ---
#
# submitit ERROR (2019-11-10 19:19:09,657) - Submitted job triggered an exception
#
# submitit INFO (2019-11-10 19:19:00,004) - Starting with JobEnvironment(job_id=20038297_18, hostname=learnfair0417, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:19:00,004) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_18/20038297_18_submitted.pkl
#
# --- Training zs-mnist/GridedCCP_varyingk_nobias/k7/run_5 ---
#
# submitit ERROR (2019-11-10 19:19:09,023) - Submitted job triggered an exception
#
# --------------------------------
# submitit INFO (2019-11-10 19:19:26,949) - Starting with JobEnvironment(job_id=20038297_19, hostname=learnfair0509, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:19:26,949) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_19/20038297_19_submitted.pkl
#
# submitit INFO (2019-11-10 19:19:26,949) - Starting with JobEnvironment(job_id=20038297_19, hostname=learnfair0509, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:19:26,949) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_19/20038297_19_submitted.pkl
#
# --------------------------------
# submitit INFO (2019-11-10 19:19:26,949) - Starting with JobEnvironment(job_id=20038297_20, hostname=learnfair0509, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:19:26,950) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_20/20038297_20_submitted.pkl
#
# submitit INFO (2019-11-10 19:19:26,949) - Starting with JobEnvironment(job_id=20038297_20, hostname=learnfair0509, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:19:26,950) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_20/20038297_20_submitted.pkl
#
# --------------------------------
# submitit INFO (2019-11-10 19:19:26,990) - Starting with JobEnvironment(job_id=20038297_21, hostname=learnfair0398, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:19:26,991) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_21/20038297_21_submitted.pkl
#
# submitit INFO (2019-11-10 19:19:26,990) - Starting with JobEnvironment(job_id=20038297_21, hostname=learnfair0398, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:19:26,991) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_21/20038297_21_submitted.pkl
#
# --------------------------------
# submitit INFO (2019-11-10 19:19:30,049) - Starting with JobEnvironment(job_id=20038297_22, hostname=learnfair0402, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:19:30,049) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_22/20038297_22_submitted.pkl
#
# submitit INFO (2019-11-10 19:19:30,049) - Starting with JobEnvironment(job_id=20038297_22, hostname=learnfair0402, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:19:30,049) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_22/20038297_22_submitted.pkl
#
# --------------------------------
# submitit INFO (2019-11-10 19:19:30,049) - Starting with JobEnvironment(job_id=20038297_23, hostname=learnfair0405, local_rank=0(2), node=0(1), global_rank=0(2))
# submitit INFO (2019-11-10 19:19:30,049) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_23/20038297_23_submitted.pkl
#
# submitit INFO (2019-11-10 19:19:30,049) - Starting with JobEnvironment(job_id=20038297_23, hostname=learnfair0405, local_rank=1(2), node=0(1), global_rank=1(2))
# submitit INFO (2019-11-10 19:19:30,049) - Loading pickle: /private/home/yannd/projects/Neural-Process-Family/logs/20038297_23/20038297_23_submitted.pkl

# %%
for j in job_64_ccp:
    print("--------------------------------")
    print(j.stderr())
# Out:
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# submitit ERROR (2019-11-10 19:17:37,440) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/_submit.py", line 5, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-fcac4eec7b45>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 237, in main
#     chckpnt_dirname=args.chckpnt_dirname,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 199, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 848, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 807, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 739, in fit_loop
#     step = self.train_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 664, in train_step
#     self.optimizer_.step(step_fn)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/optim/adam.py", line 58, in step
#     loss = closure()
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 661, in step_fn
#     step = self.train_step_single(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 603, in train_step_single
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 995, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 277, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 568, in deterministic_path
#     pseudo_values = self.inp_to_pseudo(keys, pseudo_keys, values)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 718, in inp_to_pseudo
#     batch_size, self.y_dim, *grid_shape
# RuntimeError: shape '[16, 1, 56, 56]' is invalid for input of size 33856
# srun: error: learnfair0398: task 1: Exited with exit code 1
# srun: error: learnfair0398: task 0: Exited with exit code 1
#
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# submitit ERROR (2019-11-10 19:17:37,441) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/_submit.py", line 5, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-fcac4eec7b45>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 237, in main
#     chckpnt_dirname=args.chckpnt_dirname,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 199, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 848, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 807, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 739, in fit_loop
#     step = self.train_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 664, in train_step
#     self.optimizer_.step(step_fn)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/optim/adam.py", line 58, in step
#     loss = closure()
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 661, in step_fn
#     step = self.train_step_single(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 603, in train_step_single
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 995, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 277, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 568, in deterministic_path
#     pseudo_values = self.inp_to_pseudo(keys, pseudo_keys, values)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 718, in inp_to_pseudo
#     batch_size, self.y_dim, *grid_shape
# RuntimeError: shape '[16, 1, 56, 56]' is invalid for input of size 33856
#
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# submitit ERROR (2019-11-10 19:17:37,736) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/_submit.py", line 5, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-fcac4eec7b45>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 237, in main
#     chckpnt_dirname=args.chckpnt_dirname,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 199, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 848, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 807, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 739, in fit_loop
#     step = self.train_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 664, in train_step
#     self.optimizer_.step(step_fn)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/optim/adam.py", line 58, in step
#     loss = closure()
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 661, in step_fn
#     step = self.train_step_single(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 603, in train_step_single
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 995, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 277, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 568, in deterministic_path
#     pseudo_values = self.inp_to_pseudo(keys, pseudo_keys, values)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 718, in inp_to_pseudo
#     batch_size, self.y_dim, *grid_shape
# RuntimeError: shape '[16, 1, 56, 56]' is invalid for input of size 33856
# srun: error: learnfair0402: task 0: Exited with exit code 1
# srun: error: learnfair0402: task 1: Exited with exit code 1
#
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# submitit ERROR (2019-11-10 19:17:37,738) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/_submit.py", line 5, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-fcac4eec7b45>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 237, in main
#     chckpnt_dirname=args.chckpnt_dirname,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 199, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 848, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 807, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 739, in fit_loop
#     step = self.train_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 664, in train_step
#     self.optimizer_.step(step_fn)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/optim/adam.py", line 58, in step
#     loss = closure()
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 661, in step_fn
#     step = self.train_step_single(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 603, in train_step_single
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 995, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 277, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 568, in deterministic_path
#     pseudo_values = self.inp_to_pseudo(keys, pseudo_keys, values)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 718, in inp_to_pseudo
#     batch_size, self.y_dim, *grid_shape
# RuntimeError: shape '[16, 1, 56, 56]' is invalid for input of size 33856
#
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# submitit ERROR (2019-11-10 19:17:37,717) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/_submit.py", line 5, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-fcac4eec7b45>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 237, in main
#     chckpnt_dirname=args.chckpnt_dirname,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 199, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 848, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 807, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 739, in fit_loop
#     step = self.train_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 664, in train_step
#     self.optimizer_.step(step_fn)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/optim/adam.py", line 58, in step
#     loss = closure()
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 661, in step_fn
#     step = self.train_step_single(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 603, in train_step_single
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 995, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 277, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 568, in deterministic_path
#     pseudo_values = self.inp_to_pseudo(keys, pseudo_keys, values)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 718, in inp_to_pseudo
#     batch_size, self.y_dim, *grid_shape
# RuntimeError: shape '[16, 1, 56, 56]' is invalid for input of size 33856
# srun: error: learnfair0405: task 1: Exited with exit code 1
# srun: error: learnfair0405: task 0: Exited with exit code 1
#
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# submitit ERROR (2019-11-10 19:17:37,462) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/_submit.py", line 5, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-fcac4eec7b45>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 237, in main
#     chckpnt_dirname=args.chckpnt_dirname,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 199, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 848, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 807, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 739, in fit_loop
#     step = self.train_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 664, in train_step
#     self.optimizer_.step(step_fn)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/optim/adam.py", line 58, in step
#     loss = closure()
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 661, in step_fn
#     step = self.train_step_single(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 603, in train_step_single
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 995, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 277, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 568, in deterministic_path
#     pseudo_values = self.inp_to_pseudo(keys, pseudo_keys, values)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 718, in inp_to_pseudo
#     batch_size, self.y_dim, *grid_shape
# RuntimeError: shape '[16, 1, 56, 56]' is invalid for input of size 33856
#
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# submitit ERROR (2019-11-10 19:17:58,209) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/_submit.py", line 5, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-fcac4eec7b45>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 237, in main
#     chckpnt_dirname=args.chckpnt_dirname,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 199, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 848, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 807, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 739, in fit_loop
#     step = self.train_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 664, in train_step
#     self.optimizer_.step(step_fn)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/optim/adam.py", line 58, in step
#     loss = closure()
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 661, in step_fn
#     step = self.train_step_single(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 603, in train_step_single
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 995, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 277, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 568, in deterministic_path
#     pseudo_values = self.inp_to_pseudo(keys, pseudo_keys, values)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 718, in inp_to_pseudo
#     batch_size, self.y_dim, *grid_shape
# RuntimeError: shape '[16, 1, 56, 56]' is invalid for input of size 33856
# srun: error: learnfair0398: tasks 0-1: Exited with exit code 1
#
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# submitit ERROR (2019-11-10 19:17:58,207) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/_submit.py", line 5, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-fcac4eec7b45>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 237, in main
#     chckpnt_dirname=args.chckpnt_dirname,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 199, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 848, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 807, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 739, in fit_loop
#     step = self.train_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 664, in train_step
#     self.optimizer_.step(step_fn)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/optim/adam.py", line 58, in step
#     loss = closure()
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 661, in step_fn
#     step = self.train_step_single(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 603, in train_step_single
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 995, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 277, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 568, in deterministic_path
#     pseudo_values = self.inp_to_pseudo(keys, pseudo_keys, values)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 718, in inp_to_pseudo
#     batch_size, self.y_dim, *grid_shape
# RuntimeError: shape '[16, 1, 56, 56]' is invalid for input of size 33856
#
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# submitit ERROR (2019-11-10 19:17:58,502) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/_submit.py", line 5, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-fcac4eec7b45>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 237, in main
#     chckpnt_dirname=args.chckpnt_dirname,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 199, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 848, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 807, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 739, in fit_loop
#     step = self.train_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 664, in train_step
#     self.optimizer_.step(step_fn)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/optim/adam.py", line 58, in step
#     loss = closure()
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 661, in step_fn
#     step = self.train_step_single(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 603, in train_step_single
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 995, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 277, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 568, in deterministic_path
#     pseudo_values = self.inp_to_pseudo(keys, pseudo_keys, values)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 718, in inp_to_pseudo
#     batch_size, self.y_dim, *grid_shape
# RuntimeError: shape '[16, 1, 56, 56]' is invalid for input of size 33856
# srun: error: learnfair0402: task 0: Exited with exit code 1
# srun: error: learnfair0402: task 1: Exited with exit code 1
#
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# submitit ERROR (2019-11-10 19:17:58,503) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/_submit.py", line 5, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-fcac4eec7b45>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 237, in main
#     chckpnt_dirname=args.chckpnt_dirname,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 199, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 848, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 807, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 739, in fit_loop
#     step = self.train_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 664, in train_step
#     self.optimizer_.step(step_fn)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/optim/adam.py", line 58, in step
#     loss = closure()
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 661, in step_fn
#     step = self.train_step_single(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 603, in train_step_single
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 995, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 277, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 568, in deterministic_path
#     pseudo_values = self.inp_to_pseudo(keys, pseudo_keys, values)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 718, in inp_to_pseudo
#     batch_size, self.y_dim, *grid_shape
# RuntimeError: shape '[16, 1, 56, 56]' is invalid for input of size 33856
#
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# submitit ERROR (2019-11-10 19:17:58,447) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/_submit.py", line 5, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-fcac4eec7b45>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 237, in main
#     chckpnt_dirname=args.chckpnt_dirname,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 199, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 848, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 807, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 739, in fit_loop
#     step = self.train_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 664, in train_step
#     self.optimizer_.step(step_fn)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/optim/adam.py", line 58, in step
#     loss = closure()
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 661, in step_fn
#     step = self.train_step_single(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 603, in train_step_single
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 995, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 277, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 568, in deterministic_path
#     pseudo_values = self.inp_to_pseudo(keys, pseudo_keys, values)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 718, in inp_to_pseudo
#     batch_size, self.y_dim, *grid_shape
# RuntimeError: shape '[16, 1, 56, 56]' is invalid for input of size 33856
# srun: error: learnfair0405: task 1: Exited with exit code 1
# srun: error: learnfair0405: task 0: Exited with exit code 1
#
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# submitit ERROR (2019-11-10 19:17:58,037) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/_submit.py", line 5, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-fcac4eec7b45>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 237, in main
#     chckpnt_dirname=args.chckpnt_dirname,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 199, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 848, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 807, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 739, in fit_loop
#     step = self.train_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 664, in train_step
#     self.optimizer_.step(step_fn)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/optim/adam.py", line 58, in step
#     loss = closure()
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 661, in step_fn
#     step = self.train_step_single(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 603, in train_step_single
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 995, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 277, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 568, in deterministic_path
#     pseudo_values = self.inp_to_pseudo(keys, pseudo_keys, values)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 718, in inp_to_pseudo
#     batch_size, self.y_dim, *grid_shape
# RuntimeError: shape '[16, 1, 56, 56]' is invalid for input of size 33856
#
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# submitit ERROR (2019-11-10 19:17:59,872) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/_submit.py", line 5, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-fcac4eec7b45>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 237, in main
#     chckpnt_dirname=args.chckpnt_dirname,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 199, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 848, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 807, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 739, in fit_loop
#     step = self.train_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 664, in train_step
#     self.optimizer_.step(step_fn)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/optim/adam.py", line 58, in step
#     loss = closure()
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 661, in step_fn
#     step = self.train_step_single(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 603, in train_step_single
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 995, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 277, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 568, in deterministic_path
#     pseudo_values = self.inp_to_pseudo(keys, pseudo_keys, values)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 718, in inp_to_pseudo
#     batch_size, self.y_dim, *grid_shape
# RuntimeError: shape '[16, 1, 56, 56]' is invalid for input of size 33856
# srun: error: learnfair0411: tasks 0-1: Exited with exit code 1
#
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# submitit ERROR (2019-11-10 19:17:59,871) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/_submit.py", line 5, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-fcac4eec7b45>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 237, in main
#     chckpnt_dirname=args.chckpnt_dirname,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 199, in train
#     **kwargs,
# ...
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 739, in fit_loop
#     step = self.train_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 664, in train_step
#     self.optimizer_.step(step_fn)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/optim/adam.py", line 58, in step
#     loss = closure()
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 661, in step_fn
#     step = self.train_step_single(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 603, in train_step_single
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 995, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 277, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 568, in deterministic_path
#     pseudo_values = self.inp_to_pseudo(keys, pseudo_keys, values)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 718, in inp_to_pseudo
#     batch_size, self.y_dim, *grid_shape
# RuntimeError: shape '[16, 1, 56, 56]' is invalid for input of size 33856
#
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# submitit ERROR (2019-11-10 19:19:08,476) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/_submit.py", line 5, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-fcac4eec7b45>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 237, in main
#     chckpnt_dirname=args.chckpnt_dirname,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 199, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 848, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 807, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 739, in fit_loop
#     step = self.train_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 664, in train_step
#     self.optimizer_.step(step_fn)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/optim/adam.py", line 58, in step
#     loss = closure()
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 661, in step_fn
#     step = self.train_step_single(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 603, in train_step_single
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 995, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 277, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 568, in deterministic_path
#     pseudo_values = self.inp_to_pseudo(keys, pseudo_keys, values)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 718, in inp_to_pseudo
#     batch_size, self.y_dim, *grid_shape
# RuntimeError: shape '[16, 1, 56, 56]' is invalid for input of size 33856
# srun: error: learnfair0417: task 0: Exited with exit code 1
# srun: error: learnfair0417: task 1: Exited with exit code 1
#
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# submitit ERROR (2019-11-10 19:19:08,612) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/_submit.py", line 5, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-fcac4eec7b45>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 237, in main
#     chckpnt_dirname=args.chckpnt_dirname,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 199, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 848, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 807, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 739, in fit_loop
#     step = self.train_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 664, in train_step
#     self.optimizer_.step(step_fn)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/optim/adam.py", line 58, in step
#     loss = closure()
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 661, in step_fn
#     step = self.train_step_single(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 603, in train_step_single
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 995, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 277, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 568, in deterministic_path
#     pseudo_values = self.inp_to_pseudo(keys, pseudo_keys, values)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 718, in inp_to_pseudo
#     batch_size, self.y_dim, *grid_shape
# RuntimeError: shape '[16, 1, 56, 56]' is invalid for input of size 33856
#
# --------------------------------
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# srun: error: learnfair0417: task 1: Exited with exit code 1
# submitit ERROR (2019-11-10 19:19:09,657) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/_submit.py", line 5, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-fcac4eec7b45>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 237, in main
#     chckpnt_dirname=args.chckpnt_dirname,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 199, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 848, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 807, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 739, in fit_loop
#     step = self.train_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 664, in train_step
#     self.optimizer_.step(step_fn)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/optim/adam.py", line 58, in step
#     loss = closure()
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 661, in step_fn
#     step = self.train_step_single(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 603, in train_step_single
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 995, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 277, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 568, in deterministic_path
#     pseudo_values = self.inp_to_pseudo(keys, pseudo_keys, values)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 718, in inp_to_pseudo
#     batch_size, self.y_dim, *grid_shape
# RuntimeError: shape '[16, 1, 56, 56]' is invalid for input of size 33856
# srun: error: learnfair0417: task 0: Exited with exit code 1
#
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# INFO:utils.data.imgs:Resizing ZeroShotMultiMNIST ...
# submitit ERROR (2019-11-10 19:19:09,023) - Submitted job triggered an exception
# ERROR:submitit:Submitted job triggered an exception
# Traceback (most recent call last):
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/_submit.py", line 5, in <module>
#     submitit_main()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 186, in submitit_main
#     process_job(args.folder)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 179, in process_job
#     raise error
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/submission.py", line 168, in process_job
#     result = delayed.result()
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/submitit/core/utils.py", line 122, in result
#     self._result = self.function(*self.args, **self.kwargs)
#   File "<ipython-input-4-fcac4eec7b45>", line 13, in __call__
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 237, in main
#     chckpnt_dirname=args.chckpnt_dirname,
#   File "/private/home/yannd/projects/Neural-Process-Family/train_imgs.py", line 199, in train
#     **kwargs,
#   File "/private/home/yannd/projects/Neural-Process-Family/utils/train.py", line 216, in train_models
#     _ = trainer.fit(data_train)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 848, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 807, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 739, in fit_loop
#     step = self.train_step(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 664, in train_step
#     self.optimizer_.step(step_fn)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/optim/adam.py", line 58, in step
#     loss = closure()
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 661, in step_fn
#     step = self.train_step_single(Xi, yi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 603, in train_step_single
#     y_pred = self.infer(Xi, **fit_params)
#   File "/private/home/yannd/projects/skorch/skorch/net.py", line 995, in infer
#     return self.module_(**x_dict)
#   File "/private/home/yannd/.conda/envs/assl/lib/python3.7/site-packages/torch/nn/modules/module.py", line 547, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 277, in forward
#     R_det = self.deterministic_path(X_cntxt, Y_cntxt, X_trgt)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 568, in deterministic_path
#     pseudo_values = self.inp_to_pseudo(keys, pseudo_keys, values)
#   File "/private/home/yannd/projects/Neural-Process-Family/neuralproc/neuralproc.py", line 718, in inp_to_pseudo
#     batch_size, self.y_dim, *grid_shape
# RuntimeError: shape '[16, 1, 56, 56]' is invalid for input of size 33856
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------
#
#
# --------------------------------

# %%
for j in job_64_ccp:
    j.cancel()

# %%
import seaborn as sns
import pandas as pd
from glob import glob
import numpy as np

dfs = []
prfx = "results/iclr-rebuttals/zs-mnist/GridedCCP_varyingk_nobias/k"
for g in glob(f"{prfx}*/run*/eval.csv"):
    test_loglike = np.loadtxt(g, delimiter=",").mean()
    sffx = g[len(prfx):]
    splitted = sffx.split("/")
    kernel = int(splitted[0])
    receptive_field = 11 + (kernel//2 * 5 *2)
    run = int(splitted[1][len("run_"):])
    dfs.append([receptive_field,run,test_loglike])
    
    
df = pd.DataFrame(dfs,columns=["Size of Receptive Field","run","Test Log Likelihood"])

# %%
# %autosave 600
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# CENTER PLOTS
from IPython.core.display import HTML
display(HTML(""" <style> .output_png {display: table-cell; text-align: center; margin:auto; }
.prompt display:none;}  </style>"""))
  
import sys
sys.path.append("notebooks")

import numpy as np
import matplotlib.pyplot as plt
import torch
# Out:
# Autosaving every 600 seconds
#  <style> .output_png {display: table-cell; text-align: center; margin:auto; }
# .prompt display:none;}  </style>

# %%
plt.rcParams.update({"font.size": 14})
fig, ax = plt.subplots(1,1,figsize=(17,10))
ax.axvline(56, ls='--', color="tab:red", alpha=0.5, label="Size of Image")
ax.axvline(66, ls='--', color="tab:green", alpha=0.5, label="Size of Image + Padding")
sns.lineplot(x="Size of Receptive Field", y="Test Log Likelihood", data=df, ax=ax, label="Zero Shot Translated MNIST")
sns.despine()

# %%
import seaborn as sns
import pandas as pd
from glob import glob
import numpy as np

dfs_zs_tmnist = []
prfx = "results/iclr-rebuttals/zs-mnist/GridedCCP_varyingk/k"
for g in glob(f"{prfx}*/run*/eval.csv"):
    test_loglike = np.loadtxt(g, delimiter=",").mean()
    sffx = g[len(prfx):]
    splitted = sffx.split("/")
    kernel = int(splitted[0])
    receptive_field = 11 + (kernel//2 * 5 *2)
    run = int(splitted[1][len("run_"):])
    dfs_zs_tmnist.append(["Zero Shot Translated MNIST",receptive_field,run,test_loglike])
    
dfs_zs_mmnist = []
prfx = "results/iclr-rebuttals/zs-multi-mnist/GridedCCP_varyingk/k"
for g in glob(f"{prfx}*/run*/eval.csv"):
    test_loglike = np.loadtxt(g, delimiter=",").mean()
    sffx = g[len(prfx):]
    splitted = sffx.split("/")
    kernel = int(splitted[0])
    receptive_field = 11 + (kernel//2 * 5 *2)
    run = int(splitted[1][len("run_"):])
    dfs_zs_mmnist.append(["Zeo Shot Multi MNIST", receptive_field,run,test_loglike])
    
    
    
df_zs_tmnist = pd.DataFrame(dfs_zs_tmnist,columns=["Dataset","Size of Receptive Field","run","Test Log Likelihood"])
df_zs_mmnist = pd.DataFrame(dfs_zs_mmnist,columns=["Dataset","Size of Receptive Field","run","Test Log Likelihood"])

df_zs_mmnist["Test Log Likelihood"]/= df_zs_mmnist.loc[df_zs_mmnist["Size of Receptive Field"]==21,"Test Log Likelihood"].mean()
df_zs_tmnist["Test Log Likelihood"]/= df_zs_tmnist.loc[df_zs_tmnist["Size of Receptive Field"]==21,"Test Log Likelihood"].mean()

df = pd.concat([df_zs_mmnist, df_zs_tmnist])

plt.rcParams.update({"font.size": 14})
fig, ax = plt.subplots(1,1,figsize=(17,10))
ax.axvline(56, ls='--', color="tab:red", alpha=0.5, label="Size of Image")
ax.axvline(66, ls='--', color="tab:green", alpha=0.5, label="Size of Image + Padding")
sns.lineplot(x="Size of Receptive Field", y="Test Log Likelihood", hue="Dataset", data=df, ax=ax)
sns.despine()
